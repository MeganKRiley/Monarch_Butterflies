# %% [markdown]
# # Journey North Egg First Sightings

# %%
#  Import and read
import pandas as pd 
import numpy as np
import json
# Sue Mottet 2-19-2022

# %% [markdown]
# # geoJSONifier

# %%
def df_to_geojson(df, properties, lat='latitude', lon='longitude'):
    # create a new python dict to contain our geojson data, using geojson format
    geojson = {'type':'FeatureCollection', 'features':[]}

    # loop through each row in the dataframe and convert each row to geojson format
    for _, row in df.iterrows():
        # create a feature template to fill in
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}

        # fill in the coordinates
        feature['geometry']['coordinates'] = [row[lon],row[lat]]

        # for each column, get the value and add it as a new feature property
        for prop in properties:
            feature['properties'][prop] = row[prop]
        
        # add this feature (aka, converted dataframe row) to the list of features inside our dict
        geojson['features'].append(feature)
    
    return geojson

# %% [markdown]
# # Load file

# %%
JNorth1996_2020_df = pd.read_csv("UWMadisonArb_JNorth_Project_MonarchsAndMilkweed_1996-2020.csv")
JNorth1996_2020_df.head()
# Out:
# C:\Users\motte\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           id sighting_date                species  number  latitude  \
# 0  850841703    1996-12-16  Monarch Adult Sighted       1    27.594
# 1  851824801    1996-12-06  Monarch Adult Sighted       1    30.420
# 2  854409931    1996-09-21  Monarch Adult Sighted       1    40.817
# 3  854557206    1996-09-21  Monarch Adult Sighted       1    40.817
# 4  855061862    1997-01-01  Monarch Adult Sighted       1    34.244
#
#    longitude  flag_location  \
# 0    -81.362              0
# 1    -87.224              0
# 2    -96.710              0
# 3    -96.710              0
# 4    -77.946              0
#
#                                             comments  \
# 0  On the ballfield a solitary monarch butterfly ...
# ...

# %% [markdown]
# # Data Exploratory

# %%
JNorth1996_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227433 entries, 0 to 227432
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             227433 non-null  int64
#  1   sighting_date  227433 non-null  object
#  2   species        227433 non-null  object
#  3   number         227433 non-null  int64
#  4   latitude       227433 non-null  float64
#  5   longitude      227433 non-null  float64
#  6   flag_location  227433 non-null  int64
#  7   comments       227433 non-null  object
#  8   school         227433 non-null  object
#  9   grade          227433 non-null  float64
#  10  image_url      227433 non-null  object
#  11  customerid     227433 non-null  int64
#  12  number_old     227433 non-null  float64
#  13  flag_number    227433 non-null  int64
#  14  species_old    227433 non-null  object
#  15  flag_species   227433 non-null  int64
# dtypes: float64(4), int64(6), object(6)
# ...

# %%
str(JNorth1996_2020_df.columns.tolist())
# Out:
# "['id', 'sighting_date', 'species', 'number', 'latitude', 'longitude', 'flag_location', 'comments', 'school', 'grade', 'image_url', 'customerid', 'number_old', 'flag_number', 'species_old', 'flag_species']"

# %%
JNorth1996_2020_df.describe()
# Out:
#                  id        number       latitude      longitude  \
# count  2.274330e+05  2.274330e+05  227433.000000  227433.000000
# mean   1.420650e+09  1.186529e+02      38.400690     -87.569965
# std    1.456887e+08  2.209080e+04       5.268651      10.880362
# min    8.508417e+08 -1.700000e+01     -12.100000    -165.107000
# 25%    1.377751e+09  1.000000e+00      34.723000     -95.268000
# 50%    1.477448e+09  1.000000e+00      39.503000     -86.787000
# 75%    1.526383e+09  3.000000e+00      42.409000     -79.255000
# max    1.526525e+09  1.000000e+07      65.136000     -52.883000
#
#        flag_location          grade    customerid    number_old  \
# count  227433.000000  227433.000000  2.274330e+05  2.274330e+05
# mean        0.598018 -907386.217597  9.451737e+06 -2.844270e+05
# std         0.490299  289894.342744  2.193961e+06  4.518136e+05
# min         0.000000 -999999.999000  0.000000e+00 -1.000000e+06
# 25%         0.000000 -999999.999000  9.941050e+06 -1.000000e+06
# ...

# %%
JNorth1996_2020_df.columns.tolist()
# Out:
# ['id',
#  'sighting_date',
#  'species',
#  'number',
#  'latitude',
#  'longitude',
#  'flag_location',
#  'comments',
#  'school',
#  'grade',
#  'image_url',
#  'customerid',
#  'number_old',
#  'flag_number',
#  'species_old',
#  'flag_species']

# %%
JNorth1996_2020_df.shape
# Out:
# (227433, 16)

# %%
# Determine the number of unique values in each column.
for col in JNorth1996_2020_df:
  print(JNorth1996_2020_df[col].unique())
# Out:
# [ 850841703  851824801  854409931 ... 1526524404 1526524405 1526525021]
# ['1996-12-16' '1996-12-06' '1996-09-21' ... '2020-12-29' '2020-12-30'
#  '2020-12-31']
# ['Monarch Adult Sighted' 'Monarch Adult (FIRST sighted)'
#  'Monarch Egg (FIRST sighted)' 'Monarch (OTHER Observations)'
#  'Monarch Larva (FIRST sighted)' 'Monarch PEAK Migration'
#  'Milkweed (FIRST sighted)' 'Monarch Fall Roost' 'Monarch Egg Sighted'
#  'Monarch Larva Sighted' 'Monarch, Captive-Reared' 'Milkweed Sighted']
# [       1      150       20       89       30     2000       50     7500
#        23      200        5      300        4      100       71      120
#       325       21       28     5000    20000       36       25        6
#        54     1000      160       24       60       37        2     3000
#   1000000       10  2000000       40       85       65       15        8
#       500       14      112       75       80    15000       18    10000
# ...

# %%
# Determine the number of unique values in each column.
for col in JNorth1996_2020_df:
  print(JNorth1996_2020_df[col].value_counts())
# Out:
# 850841703     1
# 1526350827    1
# 1526350816    1
# 1526350817    1
# 1526350818    1
#              ..
# 1432512422    1
# 1432519704    1
# 1432562236    1
# 1432562641    1
# 1526525021    1
# Name: id, Length: 227433, dtype: int64
# 2018-08-22    392
# 2018-10-03    377
# 2018-09-06    353
# 2019-09-19    337
# 2018-09-12    335
#              ...
# 2015-12-31      1
# 2015-11-24      1
# 2015-11-22      1
# 2006-07-30      1
# 1996-12-16      1
# Name: sighting_date, Length: 7491, dtype: int64
# Monarch Adult Sighted            102306
# Monarch Adult (FIRST sighted)     36409
# Monarch Larva Sighted             17378
# Monarch, Captive-Reared           14339
# Monarch (OTHER Observations)      13581
# Monarch Egg Sighted                8736
# Milkweed (FIRST sighted)           8465
# Monarch PEAK Migration             7689
# Monarch Egg (FIRST sighted)        6876
# Monarch Fall Roost                 5035
# Monarch Larva (FIRST sighted)      4898
# ...

# %%
# Find null values
for column in JNorth1996_2020_df.columns:
   print(f"Column {column} has {JNorth1996_2020_df[column].isnull().sum()} null values")
# Out:
# Column id has 0 null values
# Column sighting_date has 0 null values
# Column species has 0 null values
# Column number has 0 null values
# Column latitude has 0 null values
# Column longitude has 0 null values
# Column flag_location has 0 null values
# Column comments has 0 null values
# Column school has 0 null values
# Column grade has 0 null values
# Column image_url has 0 null values
# Column customerid has 0 null values
# Column number_old has 0 null values
# Column flag_number has 0 null values
# Column species_old has 0 null values
# Column flag_species has 0 null values

# %%
# Find duplicate entries
print(f"Duplicate entries: {JNorth1996_2020_df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# filtering by type of observation (Monarch Egg First Sighted)
JNorth_Egg_First_Site_df = JNorth1996_2020_df[JNorth1996_2020_df['species']=='Monarch Egg (FIRST sighted)']
JNorth_Egg_First_Site_df.head()
# Out:
#             id sighting_date                      species  number  latitude  \
# 690  887156075    1998-02-10  Monarch Egg (FIRST sighted)       1    28.529
# 693  887284032    1998-02-12  Monarch Egg (FIRST sighted)       1    28.529
# 697  887408443    1998-02-13  Monarch Egg (FIRST sighted)       1    28.807
# 698  887552426    1998-01-01  Monarch Egg (FIRST sighted)       1    27.980
# 708  888551397    1998-02-26  Monarch Egg (FIRST sighted)       1    28.807
#
#      longitude  flag_location  \
# 690    -96.679              0
# 693    -96.679              0
# 697    -96.979              0
# 698    -82.781              0
# 708    -96.979              0
#
#                                               comments  \
# 690  We gathered 21 Monarch eggs during week of Dec...
# 693  Have had a few Monarchs overwintering in this ...
# 697  Three new Monarch eggs today.  On "backup" Asc...
# 698  We have milkweed, lantana and other butterfly ...
# ...

# %%
JNorth_Egg_First_Site_df.to_csv('JNorth_Egg_First_Site.csv', header=True, mode='w' )

# %%
JNorth_Egg_First_Site_df.shape
# Out:
# (6876, 16)

# %% [markdown]
# # Format file for geoJSON

# %%
JNorth_Egg_First_Site_df = pd.DataFrame(JNorth_Egg_First_Site_df)
JNorth_Egg_First_Site_df.drop(['id','flag_location', 'comments','school','grade','image_url','customerid','number_old','flag_number','species_old','flag_species'], axis=1, inplace=True)
JNorth_Egg_First_Site_df.head()
# Out:
#     sighting_date                      species  number  latitude  longitude
# 690    1998-02-10  Monarch Egg (FIRST sighted)       1    28.529    -96.679
# 693    1998-02-12  Monarch Egg (FIRST sighted)       1    28.529    -96.679
# 697    1998-02-13  Monarch Egg (FIRST sighted)       1    28.807    -96.979
# 698    1998-01-01  Monarch Egg (FIRST sighted)       1    27.980    -82.781
# 708    1998-02-26  Monarch Egg (FIRST sighted)       1    28.807    -96.979

# %%
cols = ['sighting_date', 'species', 'number', 'latitude', 'longitude']

# %%
JNorth_Egg_First_Site_df =JNorth_Egg_First_Site_df.groupby(['sighting_date', 'species', 'latitude', 'longitude']).sum().reset_index()
JNorth_Egg_First_Site_df.head()
# Out:
#   sighting_date                      species  latitude  longitude  number
# 0    1997-06-28  Monarch Egg (FIRST sighted)    43.067    -77.214       1
# 1    1998-01-01  Monarch Egg (FIRST sighted)    27.980    -82.781       1
# 2    1998-02-01  Monarch Egg (FIRST sighted)    30.449    -91.188       1
# 3    1998-02-07  Monarch Egg (FIRST sighted)    29.385    -95.788       1
# 4    1998-02-10  Monarch Egg (FIRST sighted)    28.529    -96.679       1

# %%
JNorth_Egg_First_Site_df.columns.tolist()
# Out:
# ['sighting_date', 'species', 'latitude', 'longitude', 'number']

# %%
JNorth_Egg_First_Site_df.head()
# Out:
#   sighting_date                      species  latitude  longitude  number
# 0    1997-06-28  Monarch Egg (FIRST sighted)    43.067    -77.214       1
# 1    1998-01-01  Monarch Egg (FIRST sighted)    27.980    -82.781       1
# 2    1998-02-01  Monarch Egg (FIRST sighted)    30.449    -91.188       1
# 3    1998-02-07  Monarch Egg (FIRST sighted)    29.385    -95.788       1
# 4    1998-02-10  Monarch Egg (FIRST sighted)    28.529    -96.679       1

# %%
JNorth_Egg_First_Site_df.shape
# Out:
# (6776, 5)

# %%
JNorth_Egg_First_Site_year_df = JNorth_Egg_First_Site_df
JNorth_Egg_First_Site_year_df['year'] = pd.DatetimeIndex(JNorth_Egg_First_Site_df['sighting_date']).year

# %% [markdown]
# # 2011

# %%
JNorth_Egg_First_Site_2011_df = JNorth_Egg_First_Site_year_df[JNorth_Egg_First_Site_year_df['year']==2011]
JNorth_Egg_First_Site_2011_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1666    2011-07-23  Monarch Egg (FIRST sighted)    42.647    -74.575       1
# 1667    2011-07-23  Monarch Egg (FIRST sighted)    45.067    -64.633       1
# 1668    2011-07-25  Monarch Egg (FIRST sighted)    41.559    -72.510       1
# 1669    2011-07-26  Monarch Egg (FIRST sighted)    44.988    -92.692       1
# 1670    2011-07-31  Monarch Egg (FIRST sighted)    43.149    -88.123       1
#
#       year
# 1666  2011
# 1667  2011
# 1668  2011
# 1669  2011
# 1670  2011

# %%
JNorth_Egg_First_Site_2011_df.shape
# Out:
# (292, 6)

# %%
JNorth_Egg_First_Site_2011_df = pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_df.drop(['year'], axis=1, inplace=True)

# %%
JNorth_Egg_First_Site_2011_df['month'] = pd.DatetimeIndex(JNorth_Egg_First_Site_2011_df['sighting_date']).month

# %% [markdown]
# ## January

# %%
JNorth_Egg_First_Site_2011_month_df =pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_1_df = JNorth_Egg_First_Site_2011_month_df[JNorth_Egg_First_Site_2011_month_df['month']==1]
JNorth_Egg_First_Site_2011_1_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1379    2011-01-31  Monarch Egg (FIRST sighted)    29.483    -95.104       1
#
#       month
# 1379      1

# %%
JNorth_Egg_First_Site_2011_1_df.shape
# Out:
# (1, 6)

# %%
JNorth_Egg_First_Site_2011_1_df = pd.DataFrame(JNorth_Egg_First_Site_2011_1_df)
JNorth_Egg_First_Site_2011_1_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2011_1_df['latitude'] = JNorth_Egg_First_Site_2011_1_df['latitude'].astype(float)
JNorth_Egg_First_Site_2011_1_df['longitude'] = JNorth_Egg_First_Site_2011_1_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2011_1_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2011_1.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## February

# %%
JNorth_Egg_First_Site_2011_month_df =pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_2_df = JNorth_Egg_First_Site_2011_month_df[JNorth_Egg_First_Site_2011_month_df['month']==2]
JNorth_Egg_First_Site_2011_2_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1381    2011-02-15  Monarch Egg (FIRST sighted)    27.839    -82.715       1
# 1382    2011-02-15  Monarch Egg (FIRST sighted)    33.683   -118.012       1
# 1383    2011-02-16  Monarch Egg (FIRST sighted)    33.730   -117.797       1
# 1384    2011-02-20  Monarch Egg (FIRST sighted)    27.770    -82.637       1
# 1385    2011-02-22  Monarch Egg (FIRST sighted)    33.451   -112.069       2
#
#       month
# 1381      2
# 1382      2
# 1383      2
# 1384      2
# 1385      2

# %%
JNorth_Egg_First_Site_2011_2_df.shape
# Out:
# (6, 6)

# %%
JNorth_Egg_First_Site_2011_2_df= pd.DataFrame(JNorth_Egg_First_Site_2011_2_df)
JNorth_Egg_First_Site_2011_2_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2011_2_df['latitude'] = JNorth_Egg_First_Site_2011_2_df['latitude'].astype(float)
JNorth_Egg_First_Site_2011_2_df['longitude'] = JNorth_Egg_First_Site_2011_2_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2011_2_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2011_2.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## March

# %%
JNorth_Egg_First_Site_2011_month_df =pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_3_df = JNorth_Egg_First_Site_2011_month_df[JNorth_Egg_First_Site_2011_month_df['month']==3]
JNorth_Egg_First_Site_2011_3_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1423    2011-03-28  Monarch Egg (FIRST sighted)    29.821    -98.751       1
# 1424    2011-03-29  Monarch Egg (FIRST sighted)    30.508    -97.813       1
# 1425    2011-03-30  Monarch Egg (FIRST sighted)    29.469    -98.528       1
# 1426    2011-03-30  Monarch Egg (FIRST sighted)    30.214    -97.859       1
# 1427    2011-03-31  Monarch Egg (FIRST sighted)    29.757    -95.365       1
#
#       month
# 1423      3
# 1424      3
# 1425      3
# 1426      3
# 1427      3

# %%
JNorth_Egg_First_Site_2011_3_df.shape
# Out:
# (42, 6)

# %%
JNorth_Egg_First_Site_2011_3_df =pd.DataFrame(JNorth_Egg_First_Site_2011_3_df)
JNorth_Egg_First_Site_2011_3_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2011_3_df['latitude'] = JNorth_Egg_First_Site_2011_3_df['latitude'].astype(float)
JNorth_Egg_First_Site_2011_3_df['longitude'] = JNorth_Egg_First_Site_2011_3_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2011_3_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2011_3.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## April

# %%
JNorth_Egg_First_Site_2011_month_df =pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_4_df = JNorth_Egg_First_Site_2011_month_df[JNorth_Egg_First_Site_2011_month_df['month']==4]
JNorth_Egg_First_Site_2011_4_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1516    2011-04-28  Monarch Egg (FIRST sighted)    37.954    -87.391       1
# 1517    2011-04-30  Monarch Egg (FIRST sighted)    37.286    -80.098       1
# 1518    2011-04-30  Monarch Egg (FIRST sighted)    37.562    -80.511       1
# 1519    2011-04-30  Monarch Egg (FIRST sighted)    39.482    -77.348       1
# 1520    2011-04-30  Monarch Egg (FIRST sighted)    40.774    -77.058       1
#
#       month
# 1516      4
# 1517      4
# 1518      4
# 1519      4
# 1520      4

# %%
JNorth_Egg_First_Site_2011_4_df.shape
# Out:
# (93, 6)

# %%
JNorth_Egg_First_Site_2011_4_df = pd.DataFrame(JNorth_Egg_First_Site_2011_4_df)
JNorth_Egg_First_Site_2011_4_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2011_4_df['latitude'] = JNorth_Egg_First_Site_2011_4_df['latitude'].astype(float)
JNorth_Egg_First_Site_2011_4_df['longitude'] = JNorth_Egg_First_Site_2011_4_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2011_4_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2011_4.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## May

# %%
JNorth_Egg_First_Site_2011_month_df =pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_5_df = JNorth_Egg_First_Site_2011_month_df[JNorth_Egg_First_Site_2011_month_df['month']==5]
JNorth_Egg_First_Site_2011_5_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1579    2011-05-31  Monarch Egg (FIRST sighted)    42.320    -84.391       1
# 1580    2011-05-31  Monarch Egg (FIRST sighted)    42.485    -83.377       1
# 1581    2011-05-31  Monarch Egg (FIRST sighted)    42.972    -88.229       1
# 1582    2011-05-31  Monarch Egg (FIRST sighted)    44.409    -88.767       1
# 1583    2011-05-31  Monarch Egg (FIRST sighted)    44.738    -91.510       1
#
#       month
# 1579      5
# 1580      5
# 1581      5
# 1582      5
# 1583      5

# %%
JNorth_Egg_First_Site_2011_5_df.shape
# Out:
# (63, 6)

# %%
JNorth_Egg_First_Site_2011_5_df =pd.DataFrame(JNorth_Egg_First_Site_2011_5_df)
JNorth_Egg_First_Site_2011_5_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2011_5_df['latitude'] = JNorth_Egg_First_Site_2011_5_df['latitude'].astype(float)
JNorth_Egg_First_Site_2011_5_df['longitude'] = JNorth_Egg_First_Site_2011_5_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2011_5_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2011_5.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## June

# %%
JNorth_Egg_First_Site_2011_month_df =pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_6_df = JNorth_Egg_First_Site_2011_month_df[JNorth_Egg_First_Site_2011_month_df['month']==6]
JNorth_Egg_First_Site_2011_6_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1650    2011-06-19  Monarch Egg (FIRST sighted)    44.050    -79.467       1
# 1651    2011-06-19  Monarch Egg (FIRST sighted)    45.225    -94.115       1
# 1652    2011-06-20  Monarch Egg (FIRST sighted)    42.078    -87.823       1
# 1653    2011-06-25  Monarch Egg (FIRST sighted)    40.039    -84.184       2
# 1654    2011-06-26  Monarch Egg (FIRST sighted)    41.521    -90.576       1
#
#       month
# 1650      6
# 1651      6
# 1652      6
# 1653      6
# 1654      6

# %%
JNorth_Egg_First_Site_2011_6_df.shape
# Out:
# (71, 6)

# %%
JNorth_Egg_First_Site_2011_6_df=pd.DataFrame(JNorth_Egg_First_Site_2011_6_df)
JNorth_Egg_First_Site_2011_6_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2011_6_df['latitude'] = JNorth_Egg_First_Site_2011_6_df['latitude'].astype(float)
JNorth_Egg_First_Site_2011_6_df['longitude'] = JNorth_Egg_First_Site_2011_6_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2011_6_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2011_6.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## July

# %%
JNorth_Egg_First_Site_2011_month_df =pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_7_df = JNorth_Egg_First_Site_2011_month_df[JNorth_Egg_First_Site_2011_month_df['month']==7]
JNorth_Egg_First_Site_2011_7_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1666    2011-07-23  Monarch Egg (FIRST sighted)    42.647    -74.575       1
# 1667    2011-07-23  Monarch Egg (FIRST sighted)    45.067    -64.633       1
# 1668    2011-07-25  Monarch Egg (FIRST sighted)    41.559    -72.510       1
# 1669    2011-07-26  Monarch Egg (FIRST sighted)    44.988    -92.692       1
# 1670    2011-07-31  Monarch Egg (FIRST sighted)    43.149    -88.123       1
#
#       month
# 1666      7
# 1667      7
# 1668      7
# 1669      7
# 1670      7

# %%
JNorth_Egg_First_Site_2011_7_df.shape
# Out:
# (16, 6)

# %%
JNorth_Egg_First_Site_2011_7_df = pd.DataFrame(JNorth_Egg_First_Site_2011_7_df)
JNorth_Egg_First_Site_2011_7_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2011_7_df['latitude'] = JNorth_Egg_First_Site_2011_7_df['latitude'].astype(float)
JNorth_Egg_First_Site_2011_7_df['longitude'] = JNorth_Egg_First_Site_2011_7_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2011_7_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2011_7.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## August

# %%
JNorth_Egg_First_Site_2011_month_df =pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_8_df = JNorth_Egg_First_Site_2011_month_df[JNorth_Egg_First_Site_2011_month_df['month']==8]
JNorth_Egg_First_Site_2011_8_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2011_8_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2011_8_df = pd.DataFrame(JNorth_Egg_First_Site_2011_8_df)
JNorth_Egg_First_Site_2011_8_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2011_8_df['latitude'] = JNorth_Egg_First_Site_2011_8_df['latitude'].astype(float)
JNorth_Egg_First_Site_2011_8_df['longitude'] = JNorth_Egg_First_Site_2011_8_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2011_8_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2011_8.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## September

# %%
JNorth_Egg_First_Site_2011_month_df =pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_9_df = JNorth_Egg_First_Site_2011_month_df[JNorth_Egg_First_Site_2011_month_df['month']==9]
JNorth_Egg_First_Site_2011_9_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2011_9_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2011_9_df = pd.DataFrame(JNorth_Egg_First_Site_2011_9_df)
JNorth_Egg_First_Site_2011_9_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2011_9_df['latitude'] = JNorth_Egg_First_Site_2011_9_df['latitude'].astype(float)
JNorth_Egg_First_Site_2011_9_df['longitude'] = JNorth_Egg_First_Site_2011_9_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2011_9_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2011_9.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## October

# %%
JNorth_Egg_First_Site_2011_month_df =pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_10_df = JNorth_Egg_First_Site_2011_month_df[JNorth_Egg_First_Site_2011_month_df['month']==10]
JNorth_Egg_First_Site_2011_10_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2011_10_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2011_10_df = pd.DataFrame(JNorth_Egg_First_Site_2011_10_df)
JNorth_Egg_First_Site_2011_10_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2011_10_df['latitude'] = JNorth_Egg_First_Site_2011_10_df['latitude'].astype(float)
JNorth_Egg_First_Site_2011_10_df['longitude'] = JNorth_Egg_First_Site_2011_10_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2011_10_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2011_10.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## November

# %%
JNorth_Egg_First_Site_2011_month_df =pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_11_df = JNorth_Egg_First_Site_2011_month_df[JNorth_Egg_First_Site_2011_month_df['month']==11]
JNorth_Egg_First_Site_2011_11_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2011_11_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2011_11_df = pd.DataFrame(JNorth_Egg_First_Site_2011_11_df)
JNorth_Egg_First_Site_2011_11_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2011_11_df['latitude'] = JNorth_Egg_First_Site_2011_11_df['latitude'].astype(float)
JNorth_Egg_First_Site_2011_11_df['longitude'] = JNorth_Egg_First_Site_2011_11_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2011_11_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2011_11.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## December

# %%
JNorth_Egg_First_Site_2011_month_df =pd.DataFrame(JNorth_Egg_First_Site_2011_df)
JNorth_Egg_First_Site_2011_12_df = JNorth_Egg_First_Site_2011_month_df[JNorth_Egg_First_Site_2011_month_df['month']==12]
JNorth_Egg_First_Site_2011_12_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2011_12_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2011_12_df = pd.DataFrame(JNorth_Egg_First_Site_2011_12_df)
JNorth_Egg_First_Site_2011_12_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2011_12_df['latitude'] = JNorth_Egg_First_Site_2011_12_df['latitude'].astype(float)
JNorth_Egg_First_Site_2011_12_df['longitude'] = JNorth_Egg_First_Site_2011_12_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2011_12_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2011_12.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # 2012

# %%
JNorth_Egg_First_Site_2012_df = JNorth_Egg_First_Site_year_df[JNorth_Egg_First_Site_year_df['year']==2012]
JNorth_Egg_First_Site_2012_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1996    2012-07-17  Monarch Egg (FIRST sighted)    40.475    -79.954       1
# 1997    2012-07-19  Monarch Egg (FIRST sighted)    31.542   -110.513       1
# 1998    2012-07-25  Monarch Egg (FIRST sighted)    33.398   -117.554       1
# 1999    2012-07-25  Monarch Egg (FIRST sighted)    42.830    -77.724       1
# 2000    2012-07-29  Monarch Egg (FIRST sighted)    30.340    -81.831       1
#
#       year
# 1996  2012
# 1997  2012
# 1998  2012
# 1999  2012
# 2000  2012

# %%
JNorth_Egg_First_Site_2012_df.shape
# Out:
# (330, 6)

# %%
JNorth_Egg_First_Site_2012_df = pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_df.drop(['year'], axis=1, inplace=True)

# %%
JNorth_Egg_First_Site_2012_df.tail
# Out:
# <bound method NDFrame.tail of      sighting_date                      species  latitude  longitude  number
# 1671    2012-01-01  Monarch Egg (FIRST sighted)    26.623    -81.883       1
# 1672    2012-01-01  Monarch Egg (FIRST sighted)    28.529    -96.679       1
# 1673    2012-01-01  Monarch Egg (FIRST sighted)    33.451   -112.069       1
# 1674    2012-01-04  Monarch Egg (FIRST sighted)    33.324   -111.867       1
# 1675    2012-01-12  Monarch Egg (FIRST sighted)    29.836    -95.735       1
# ...            ...                          ...       ...        ...     ...
# 1996    2012-07-17  Monarch Egg (FIRST sighted)    40.475    -79.954       1
# 1997    2012-07-19  Monarch Egg (FIRST sighted)    31.542   -110.513       1
# 1998    2012-07-25  Monarch Egg (FIRST sighted)    33.398   -117.554       1
# 1999    2012-07-25  Monarch Egg (FIRST sighted)    42.830    -77.724       1
# 2000    2012-07-29  Monarch Egg (FIRST sighted)    30.340    -81.831       1
#
# ...

# %%
JNorth_Egg_First_Site_2012_df['month'] = pd.DatetimeIndex(JNorth_Egg_First_Site_2012_df['sighting_date']).month

# %% [markdown]
# ## January

# %%
JNorth_Egg_First_Site_2012_month_df =pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_1_df = JNorth_Egg_First_Site_2012_month_df[JNorth_Egg_First_Site_2012_month_df['month']==1]
JNorth_Egg_First_Site_2012_1_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1676    2012-01-19  Monarch Egg (FIRST sighted)    29.990    -90.255       1
# 1677    2012-01-20  Monarch Egg (FIRST sighted)    29.483    -95.104       1
# 1678    2012-01-21  Monarch Egg (FIRST sighted)    29.469    -98.528       1
# 1679    2012-01-30  Monarch Egg (FIRST sighted)    28.009    -82.697       1
# 1680    2012-01-30  Monarch Egg (FIRST sighted)    30.005    -90.104       1
#
#       month
# 1676      1
# 1677      1
# 1678      1
# 1679      1
# 1680      1

# %%
JNorth_Egg_First_Site_2012_1_df.shape
# Out:
# (10, 6)

# %%
JNorth_Egg_First_Site_2012_1_df = pd.DataFrame(JNorth_Egg_First_Site_2012_1_df)
JNorth_Egg_First_Site_2012_1_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2012_1_df['latitude'] = JNorth_Egg_First_Site_2012_1_df['latitude'].astype(float)
JNorth_Egg_First_Site_2012_1_df['longitude'] = JNorth_Egg_First_Site_2012_1_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2012_1_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2012_1.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## February

# %%
JNorth_Egg_First_Site_2012_month_df =pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_2_df = JNorth_Egg_First_Site_2012_month_df[JNorth_Egg_First_Site_2012_month_df['month']==2]
JNorth_Egg_First_Site_2012_2_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1683    2012-02-15  Monarch Egg (FIRST sighted)    26.988    -82.343       1
# 1684    2012-02-18  Monarch Egg (FIRST sighted)    26.990    -82.097       1
# 1685    2012-02-21  Monarch Egg (FIRST sighted)    26.988    -82.343       1
# 1686    2012-02-26  Monarch Egg (FIRST sighted)    27.792    -80.479       1
# 1687    2012-02-29  Monarch Egg (FIRST sighted)    30.047    -95.214       1
#
#       month
# 1683      2
# 1684      2
# 1685      2
# 1686      2
# 1687      2

# %%
JNorth_Egg_First_Site_2012_2_df.shape
# Out:
# (7, 6)

# %%
JNorth_Egg_First_Site_2012_2_df = pd.DataFrame(JNorth_Egg_First_Site_2012_2_df)
JNorth_Egg_First_Site_2012_2_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2012_2_df['latitude'] = JNorth_Egg_First_Site_2012_2_df['latitude'].astype(float)
JNorth_Egg_First_Site_2012_2_df['longitude'] = JNorth_Egg_First_Site_2012_2_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2012_2_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2012_2.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## March

# %%
JNorth_Egg_First_Site_2012_month_df =pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_3_df = JNorth_Egg_First_Site_2012_month_df[JNorth_Egg_First_Site_2012_month_df['month']==3]
JNorth_Egg_First_Site_2012_3_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1752    2012-03-29  Monarch Egg (FIRST sighted)    36.300    -95.980       1
# 1753    2012-03-30  Monarch Egg (FIRST sighted)    29.620    -98.450       1
# 1754    2012-03-30  Monarch Egg (FIRST sighted)    32.788    -96.800       1
# 1755    2012-03-30  Monarch Egg (FIRST sighted)    35.343    -86.240       1
# 1756    2012-03-31  Monarch Egg (FIRST sighted)    33.198    -96.615       1
#
#       month
# 1752      3
# 1753      3
# 1754      3
# 1755      3
# 1756      3

# %%
JNorth_Egg_First_Site_2012_3_df.shape
# Out:
# (69, 6)

# %%
JNorth_Egg_First_Site_2012_3_df = pd.DataFrame(JNorth_Egg_First_Site_2012_3_df)
JNorth_Egg_First_Site_2012_3_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2012_3_df['latitude'] = JNorth_Egg_First_Site_2012_3_df['latitude'].astype(float)
JNorth_Egg_First_Site_2012_3_df['longitude'] = JNorth_Egg_First_Site_2012_3_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2012_3_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2012_3.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## April

# %%
JNorth_Egg_First_Site_2012_month_df =pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_4_df = JNorth_Egg_First_Site_2012_month_df[JNorth_Egg_First_Site_2012_month_df['month']==4]
JNorth_Egg_First_Site_2012_4_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1803    2012-04-28  Monarch Egg (FIRST sighted)    40.148    -92.667       1
# 1804    2012-04-29  Monarch Egg (FIRST sighted)    39.930    -76.379       1
# 1805    2012-04-29  Monarch Egg (FIRST sighted)    40.092    -75.456       1
# 1806    2012-04-30  Monarch Egg (FIRST sighted)    38.393    -85.267       1
# 1807    2012-04-30  Monarch Egg (FIRST sighted)    39.959    -86.290       1
#
#       month
# 1803      4
# 1804      4
# 1805      4
# 1806      4
# 1807      4

# %%
JNorth_Egg_First_Site_2012_4_df.shape
# Out:
# (51, 6)

# %%
JNorth_Egg_First_Site_2012_4_df = pd.DataFrame(JNorth_Egg_First_Site_2012_4_df)
JNorth_Egg_First_Site_2012_4_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2012_4_df['latitude'] = JNorth_Egg_First_Site_2012_4_df['latitude'].astype(float)
JNorth_Egg_First_Site_2012_4_df['longitude'] = JNorth_Egg_First_Site_2012_4_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2012_4_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2012_4.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## May

# %%
JNorth_Egg_First_Site_2012_month_df =pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_5_df = JNorth_Egg_First_Site_2012_month_df[JNorth_Egg_First_Site_2012_month_df['month']==5]
JNorth_Egg_First_Site_2012_5_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1969    2012-05-26  Monarch Egg (FIRST sighted)    42.219    -83.352       1
# 1970    2012-05-26  Monarch Egg (FIRST sighted)    42.233    -83.100       1
# 1971    2012-05-27  Monarch Egg (FIRST sighted)    36.716   -119.197       1
# 1972    2012-05-27  Monarch Egg (FIRST sighted)    41.612    -86.138       1
# 1973    2012-05-30  Monarch Egg (FIRST sighted)    40.819    -74.158       1
#
#       month
# 1969      5
# 1970      5
# 1971      5
# 1972      5
# 1973      5

# %%
JNorth_Egg_First_Site_2012_5_df.shape
# Out:
# (166, 6)

# %%
JNorth_Egg_First_Site_2012_5_df = pd.DataFrame(JNorth_Egg_First_Site_2012_5_df)
JNorth_Egg_First_Site_2012_5_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2012_5_df['latitude'] = JNorth_Egg_First_Site_2012_5_df['latitude'].astype(float)
JNorth_Egg_First_Site_2012_5_df['longitude'] = JNorth_Egg_First_Site_2012_5_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2012_5_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2012_5.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## June

# %%
JNorth_Egg_First_Site_2012_month_df =pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_6_df = JNorth_Egg_First_Site_2012_month_df[JNorth_Egg_First_Site_2012_month_df['month']==6]
JNorth_Egg_First_Site_2012_6_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1980    2012-06-17  Monarch Egg (FIRST sighted)    32.760   -116.998       1
# 1981    2012-06-17  Monarch Egg (FIRST sighted)    43.068    -70.800       1
# 1982    2012-06-20  Monarch Egg (FIRST sighted)    43.590   -116.613       1
# 1983    2012-06-23  Monarch Egg (FIRST sighted)    43.700    -79.417       1
# 1984    2012-06-30  Monarch Egg (FIRST sighted)    40.215    -74.081       1
#
#       month
# 1980      6
# 1981      6
# 1982      6
# 1983      6
# 1984      6

# %%
JNorth_Egg_First_Site_2012_6_df.shape
# Out:
# (11, 6)

# %%
JNorth_Egg_First_Site_2012_6_df = pd.DataFrame(JNorth_Egg_First_Site_2012_6_df)
JNorth_Egg_First_Site_2012_6_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2012_6_df['latitude'] = JNorth_Egg_First_Site_2012_6_df['latitude'].astype(float)
JNorth_Egg_First_Site_2012_6_df['longitude'] = JNorth_Egg_First_Site_2012_6_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2012_6_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2012_6.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## July

# %%
JNorth_Egg_First_Site_2012_month_df =pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_7_df = JNorth_Egg_First_Site_2012_month_df[JNorth_Egg_First_Site_2012_month_df['month']==7]
JNorth_Egg_First_Site_2012_7_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 1996    2012-07-17  Monarch Egg (FIRST sighted)    40.475    -79.954       1
# 1997    2012-07-19  Monarch Egg (FIRST sighted)    31.542   -110.513       1
# 1998    2012-07-25  Monarch Egg (FIRST sighted)    33.398   -117.554       1
# 1999    2012-07-25  Monarch Egg (FIRST sighted)    42.830    -77.724       1
# 2000    2012-07-29  Monarch Egg (FIRST sighted)    30.340    -81.831       1
#
#       month
# 1996      7
# 1997      7
# 1998      7
# 1999      7
# 2000      7

# %%
JNorth_Egg_First_Site_2012_7_df.shape
# Out:
# (16, 6)

# %%
JNorth_Egg_First_Site_2012_7_df = pd.DataFrame(JNorth_Egg_First_Site_2012_7_df)
JNorth_Egg_First_Site_2012_7_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2012_7_df['latitude'] = JNorth_Egg_First_Site_2012_7_df['latitude'].astype(float)
JNorth_Egg_First_Site_2012_7_df['longitude'] = JNorth_Egg_First_Site_2012_7_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2012_7_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2012_7.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## August

# %%
JNorth_Egg_First_Site_2012_month_df =pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_8_df = JNorth_Egg_First_Site_2012_month_df[JNorth_Egg_First_Site_2012_month_df['month']==8]
JNorth_Egg_First_Site_2012_8_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2012_8_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2012_8_df = pd.DataFrame(JNorth_Egg_First_Site_2012_8_df)
JNorth_Egg_First_Site_2012_8_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2012_8_df['latitude'] = JNorth_Egg_First_Site_2012_8_df['latitude'].astype(float)
JNorth_Egg_First_Site_2012_8_df['longitude'] = JNorth_Egg_First_Site_2012_8_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2012_8_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2012_8.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## September

# %%
JNorth_Egg_First_Site_2012_month_df =pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_9_df = JNorth_Egg_First_Site_2012_month_df[JNorth_Egg_First_Site_2012_month_df['month']==9]
JNorth_Egg_First_Site_2012_9_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2012_9_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2012_9_df = pd.DataFrame(JNorth_Egg_First_Site_2012_9_df)
JNorth_Egg_First_Site_2012_9_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2012_9_df['latitude'] = JNorth_Egg_First_Site_2012_9_df['latitude'].astype(float)
JNorth_Egg_First_Site_2012_9_df['longitude'] = JNorth_Egg_First_Site_2012_9_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2012_9_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2012_9.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## October

# %%
JNorth_Egg_First_Site_2012_month_df =pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_10_df = JNorth_Egg_First_Site_2012_month_df[JNorth_Egg_First_Site_2012_month_df['month']==10]
JNorth_Egg_First_Site_2012_10_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2012_10_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2012_10_df = pd.DataFrame(JNorth_Egg_First_Site_2012_10_df)
JNorth_Egg_First_Site_2012_10_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2012_10_df['latitude'] = JNorth_Egg_First_Site_2012_10_df['latitude'].astype(float)
JNorth_Egg_First_Site_2012_10_df['longitude'] = JNorth_Egg_First_Site_2012_10_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2012_10_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2012_10.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## November

# %%
JNorth_Egg_First_Site_2012_month_df =pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_11_df = JNorth_Egg_First_Site_2012_month_df[JNorth_Egg_First_Site_2012_month_df['month']==11]
JNorth_Egg_First_Site_2012_11_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2012_11_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2012_11_df = pd.DataFrame(JNorth_Egg_First_Site_2012_11_df)
JNorth_Egg_First_Site_2012_11_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2012_11_df['latitude'] = JNorth_Egg_First_Site_2012_11_df['latitude'].astype(float)
JNorth_Egg_First_Site_2012_11_df['longitude'] = JNorth_Egg_First_Site_2012_11_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2012_11_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2012_11.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## December

# %%
JNorth_Egg_First_Site_2012_month_df =pd.DataFrame(JNorth_Egg_First_Site_2012_df)
JNorth_Egg_First_Site_2012_12_df = JNorth_Egg_First_Site_2012_month_df[JNorth_Egg_First_Site_2012_month_df['month']==12]
JNorth_Egg_First_Site_2012_12_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2012_12_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2012_12_df = pd.DataFrame(JNorth_Egg_First_Site_2012_12_df)
JNorth_Egg_First_Site_2012_12_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2012_12_df['latitude'] = JNorth_Egg_First_Site_2012_12_df['latitude'].astype(float)
JNorth_Egg_First_Site_2012_12_df['longitude'] = JNorth_Egg_First_Site_2012_12_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2012_12_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2012_12.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # 2013

# %%
JNorth_Egg_First_Site_2013_df = JNorth_Egg_First_Site_year_df[JNorth_Egg_First_Site_year_df['year']==2013]
JNorth_Egg_First_Site_2013_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2262    2013-07-29  Monarch Egg (FIRST sighted)    41.461    -85.023       1
# 2263    2013-07-30  Monarch Egg (FIRST sighted)    42.983    -81.233       1
# 2264    2013-08-10  Monarch Egg (FIRST sighted)    41.723    -85.976       1
# 2265    2013-08-11  Monarch Egg (FIRST sighted)    42.314    -84.032       1
# 2266    2013-08-27  Monarch Egg (FIRST sighted)    28.056    -82.676       1
#
#       year
# 2262  2013
# 2263  2013
# 2264  2013
# 2265  2013
# 2266  2013

# %%
JNorth_Egg_First_Site_2013_df.shape
# Out:
# (266, 6)

# %%
JNorth_Egg_First_Site_2013_df = pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_df.drop(['year'], axis=1, inplace=True)

# %%
JNorth_Egg_First_Site_2013_df.tail
# Out:
# <bound method NDFrame.tail of      sighting_date                      species  latitude  longitude  number
# 2001    2013-01-06  Monarch Egg (FIRST sighted)    27.954    -82.457       1
# 2002    2013-01-21  Monarch Egg (FIRST sighted)    29.996    -95.680       1
# 2003    2013-01-27  Monarch Egg (FIRST sighted)    30.449    -91.188       1
# 2004    2013-01-31  Monarch Egg (FIRST sighted)    26.990    -82.097       1
# 2005    2013-02-04  Monarch Egg (FIRST sighted)    26.990    -82.097       1
# ...            ...                          ...       ...        ...     ...
# 2262    2013-07-29  Monarch Egg (FIRST sighted)    41.461    -85.023       1
# 2263    2013-07-30  Monarch Egg (FIRST sighted)    42.983    -81.233       1
# 2264    2013-08-10  Monarch Egg (FIRST sighted)    41.723    -85.976       1
# 2265    2013-08-11  Monarch Egg (FIRST sighted)    42.314    -84.032       1
# 2266    2013-08-27  Monarch Egg (FIRST sighted)    28.056    -82.676       1
#
# ...

# %%
JNorth_Egg_First_Site_2013_df['month'] = pd.DatetimeIndex(JNorth_Egg_First_Site_2013_df['sighting_date']).month

# %% [markdown]
# ## January

# %%
JNorth_Egg_First_Site_2013_month_df =pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_1_df = JNorth_Egg_First_Site_2013_month_df[JNorth_Egg_First_Site_2013_month_df['month']==1]
JNorth_Egg_First_Site_2013_1_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2001    2013-01-06  Monarch Egg (FIRST sighted)    27.954    -82.457       1
# 2002    2013-01-21  Monarch Egg (FIRST sighted)    29.996    -95.680       1
# 2003    2013-01-27  Monarch Egg (FIRST sighted)    30.449    -91.188       1
# 2004    2013-01-31  Monarch Egg (FIRST sighted)    26.990    -82.097       1
#
#       month
# 2001      1
# 2002      1
# 2003      1
# 2004      1

# %%
JNorth_Egg_First_Site_2013_1_df.shape
# Out:
# (4, 6)

# %%
JNorth_Egg_First_Site_2013_1_df = pd.DataFrame(JNorth_Egg_First_Site_2013_1_df)
JNorth_Egg_First_Site_2013_1_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2013_1_df['latitude'] = JNorth_Egg_First_Site_2013_1_df['latitude'].astype(float)
JNorth_Egg_First_Site_2013_1_df['longitude'] = JNorth_Egg_First_Site_2013_1_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2013_1_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2013_1.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## February

# %%
JNorth_Egg_First_Site_2013_month_df =pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_2_df = JNorth_Egg_First_Site_2013_month_df[JNorth_Egg_First_Site_2013_month_df['month']==2]
JNorth_Egg_First_Site_2013_2_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2005    2013-02-04  Monarch Egg (FIRST sighted)    26.990    -82.097       1
# 2006    2013-02-15  Monarch Egg (FIRST sighted)    33.256   -116.375       1
# 2007    2013-02-23  Monarch Egg (FIRST sighted)    37.063   -122.162       1
#
#       month
# 2005      2
# 2006      2
# 2007      2

# %%
JNorth_Egg_First_Site_2013_2_df.shape
# Out:
# (3, 6)

# %%
JNorth_Egg_First_Site_2013_2_df = pd.DataFrame(JNorth_Egg_First_Site_2013_2_df)
JNorth_Egg_First_Site_2013_2_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2013_2_df['latitude'] = JNorth_Egg_First_Site_2013_2_df['latitude'].astype(float)
JNorth_Egg_First_Site_2013_2_df['longitude'] = JNorth_Egg_First_Site_2013_2_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2013_2_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2013_2.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## March

# %%
JNorth_Egg_First_Site_2013_month_df =pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_3_df = JNorth_Egg_First_Site_2013_month_df[JNorth_Egg_First_Site_2013_month_df['month']==3]
JNorth_Egg_First_Site_2013_3_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2031    2013-03-27  Monarch Egg (FIRST sighted)    29.973    -98.721       1
# 2032    2013-03-27  Monarch Egg (FIRST sighted)    31.616    -98.994       1
# 2033    2013-03-28  Monarch Egg (FIRST sighted)    28.542    -81.374       1
# 2034    2013-03-31  Monarch Egg (FIRST sighted)    29.836    -95.735       1
# 2035    2013-03-31  Monarch Egg (FIRST sighted)    32.130    -97.855       1
#
#       month
# 2031      3
# 2032      3
# 2033      3
# 2034      3
# 2035      3

# %%
JNorth_Egg_First_Site_2013_3_df.shape
# Out:
# (28, 6)

# %%
JNorth_Egg_First_Site_2013_3_df = pd.DataFrame(JNorth_Egg_First_Site_2013_3_df)
JNorth_Egg_First_Site_2013_3_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2013_3_df['latitude'] = JNorth_Egg_First_Site_2013_3_df['latitude'].astype(float)
JNorth_Egg_First_Site_2013_3_df['longitude'] = JNorth_Egg_First_Site_2013_3_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2013_3_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2013_3.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## April

# %%
JNorth_Egg_First_Site_2013_month_df =pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_4_df = JNorth_Egg_First_Site_2013_month_df[JNorth_Egg_First_Site_2013_month_df['month']==4]
JNorth_Egg_First_Site_2013_4_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2068    2013-04-23  Monarch Egg (FIRST sighted)    28.005    -82.695       1
# 2069    2013-04-25  Monarch Egg (FIRST sighted)    33.622    -95.912       1
# 2070    2013-04-26  Monarch Egg (FIRST sighted)    29.957    -90.078       1
# 2071    2013-04-27  Monarch Egg (FIRST sighted)    27.768    -80.600       1
# 2072    2013-04-29  Monarch Egg (FIRST sighted)    35.297    -96.664       1
#
#       month
# 2068      4
# 2069      4
# 2070      4
# 2071      4
# 2072      4

# %%
JNorth_Egg_First_Site_2013_4_df.shape
# Out:
# (37, 6)

# %%
JNorth_Egg_First_Site_2013_4_df =pd.DataFrame(JNorth_Egg_First_Site_2013_4_df)
JNorth_Egg_First_Site_2013_4_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2013_4_df['latitude'] = JNorth_Egg_First_Site_2013_4_df['latitude'].astype(float)
JNorth_Egg_First_Site_2013_4_df['longitude'] = JNorth_Egg_First_Site_2013_4_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2013_4_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2013_4.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## May

# %%
JNorth_Egg_First_Site_2013_month_df =pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_5_df = JNorth_Egg_First_Site_2013_month_df[JNorth_Egg_First_Site_2013_month_df['month']==5]
JNorth_Egg_First_Site_2013_5_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2109    2013-05-30  Monarch Egg (FIRST sighted)    44.546    -93.953       1
# 2110    2013-05-30  Monarch Egg (FIRST sighted)    45.011    -91.713       1
# 2111    2013-05-31  Monarch Egg (FIRST sighted)    41.627    -93.712       1
# 2112    2013-05-31  Monarch Egg (FIRST sighted)    43.056    -77.520       1
# 2113    2013-05-31  Monarch Egg (FIRST sighted)    43.594    -83.962       1
#
#       month
# 2109      5
# 2110      5
# 2111      5
# 2112      5
# 2113      5

# %%
JNorth_Egg_First_Site_2013_5_df.shape
# Out:
# (41, 6)

# %%
JNorth_Egg_First_Site_2013_5_df =pd.DataFrame(JNorth_Egg_First_Site_2013_5_df)
JNorth_Egg_First_Site_2013_5_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2013_5_df['latitude'] = JNorth_Egg_First_Site_2013_5_df['latitude'].astype(float)
JNorth_Egg_First_Site_2013_5_df['longitude'] = JNorth_Egg_First_Site_2013_5_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2013_5_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2013_5.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## June

# %%
JNorth_Egg_First_Site_2013_month_df =pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_6_df = JNorth_Egg_First_Site_2013_month_df[JNorth_Egg_First_Site_2013_month_df['month']==6]
JNorth_Egg_First_Site_2013_6_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2185    2013-06-29  Monarch Egg (FIRST sighted)    39.081    -76.558       1
# 2186    2013-06-29  Monarch Egg (FIRST sighted)    39.755    -74.124       1
# 2187    2013-06-29  Monarch Egg (FIRST sighted)    44.732    -93.218       1
# 2188    2013-06-30  Monarch Egg (FIRST sighted)    37.721    -89.191       1
# 2189    2013-06-30  Monarch Egg (FIRST sighted)    42.664    -83.236       1
#
#       month
# 2185      6
# 2186      6
# 2187      6
# 2188      6
# 2189      6

# %%
JNorth_Egg_First_Site_2013_6_df.shape
# Out:
# (76, 6)

# %%
JNorth_Egg_First_Site_2013_6_df = pd.DataFrame(JNorth_Egg_First_Site_2013_6_df)
JNorth_Egg_First_Site_2013_6_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2013_6_df['latitude'] = JNorth_Egg_First_Site_2013_6_df['latitude'].astype(float)
JNorth_Egg_First_Site_2013_6_df['longitude'] = JNorth_Egg_First_Site_2013_6_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2013_6_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2013_6.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## July

# %%
JNorth_Egg_First_Site_2013_month_df =pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_7_df = JNorth_Egg_First_Site_2013_month_df[JNorth_Egg_First_Site_2013_month_df['month']==7]
JNorth_Egg_First_Site_2013_7_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2259    2013-07-27  Monarch Egg (FIRST sighted)    44.000    -78.017       1
# 2260    2013-07-28  Monarch Egg (FIRST sighted)    42.336    -89.135       1
# 2261    2013-07-28  Monarch Egg (FIRST sighted)    43.700    -79.417       1
# 2262    2013-07-29  Monarch Egg (FIRST sighted)    41.461    -85.023       1
# 2263    2013-07-30  Monarch Egg (FIRST sighted)    42.983    -81.233       1
#
#       month
# 2259      7
# 2260      7
# 2261      7
# 2262      7
# 2263      7

# %%
JNorth_Egg_First_Site_2013_7_df.shape
# Out:
# (74, 6)

# %%
JNorth_Egg_First_Site_2013_7_df = pd.DataFrame(JNorth_Egg_First_Site_2013_7_df)
JNorth_Egg_First_Site_2013_7_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2013_7_df['latitude'] = JNorth_Egg_First_Site_2013_7_df['latitude'].astype(float)
JNorth_Egg_First_Site_2013_7_df['longitude'] = JNorth_Egg_First_Site_2013_7_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2013_7_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2013_7.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## August

# %%
JNorth_Egg_First_Site_2013_month_df =pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_8_df = JNorth_Egg_First_Site_2013_month_df[JNorth_Egg_First_Site_2013_month_df['month']==8]
JNorth_Egg_First_Site_2013_8_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2264    2013-08-10  Monarch Egg (FIRST sighted)    41.723    -85.976       1
# 2265    2013-08-11  Monarch Egg (FIRST sighted)    42.314    -84.032       1
# 2266    2013-08-27  Monarch Egg (FIRST sighted)    28.056    -82.676       1
#
#       month
# 2264      8
# 2265      8
# 2266      8

# %%
JNorth_Egg_First_Site_2013_8_df.shape
# Out:
# (3, 6)

# %%
JNorth_Egg_First_Site_2013_8_df = pd.DataFrame(JNorth_Egg_First_Site_2013_8_df)
JNorth_Egg_First_Site_2013_8_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2013_8_df['latitude'] = JNorth_Egg_First_Site_2013_8_df['latitude'].astype(float)
JNorth_Egg_First_Site_2013_8_df['longitude'] = JNorth_Egg_First_Site_2013_8_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2013_8_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2013_8.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## September

# %%
JNorth_Egg_First_Site_2013_month_df =pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_9_df = JNorth_Egg_First_Site_2013_month_df[JNorth_Egg_First_Site_2013_month_df['month']==9]
JNorth_Egg_First_Site_2013_9_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2013_9_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2013_9_df = pd.DataFrame(JNorth_Egg_First_Site_2013_9_df)
JNorth_Egg_First_Site_2013_9_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2013_9_df['latitude'] = JNorth_Egg_First_Site_2013_9_df['latitude'].astype(float)
JNorth_Egg_First_Site_2013_9_df['longitude'] = JNorth_Egg_First_Site_2013_9_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2013_9_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2013_9.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## October

# %%
JNorth_Egg_First_Site_2013_month_df =pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_10_df = JNorth_Egg_First_Site_2013_month_df[JNorth_Egg_First_Site_2013_month_df['month']==10]
JNorth_Egg_First_Site_2013_10_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2013_10_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2013_10_df = pd.DataFrame(JNorth_Egg_First_Site_2013_10_df)
JNorth_Egg_First_Site_2013_10_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2013_10_df['latitude'] = JNorth_Egg_First_Site_2013_10_df['latitude'].astype(float)
JNorth_Egg_First_Site_2013_10_df['longitude'] = JNorth_Egg_First_Site_2013_10_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2013_10_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2013_10.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## November

# %%
JNorth_Egg_First_Site_2013_month_df =pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_11_df = JNorth_Egg_First_Site_2013_month_df[JNorth_Egg_First_Site_2013_month_df['month']==11]
JNorth_Egg_First_Site_2013_11_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2013_11_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2013_11_df = pd.DataFrame(JNorth_Egg_First_Site_2013_11_df)
JNorth_Egg_First_Site_2013_11_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2013_11_df['latitude'] = JNorth_Egg_First_Site_2013_11_df['latitude'].astype(float)
JNorth_Egg_First_Site_2013_11_df['longitude'] = JNorth_Egg_First_Site_2013_11_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2013_11_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2013_11.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## December

# %%
JNorth_Egg_First_Site_2013_month_df =pd.DataFrame(JNorth_Egg_First_Site_2013_df)
JNorth_Egg_First_Site_2013_12_df = JNorth_Egg_First_Site_2013_month_df[JNorth_Egg_First_Site_2013_month_df['month']==12]
JNorth_Egg_First_Site_2013_12_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2013_12_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2013_12_df = pd.DataFrame(JNorth_Egg_First_Site_2013_12_df)
JNorth_Egg_First_Site_2013_12_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2013_12_df['latitude'] = JNorth_Egg_First_Site_2013_12_df['latitude'].astype(float)
JNorth_Egg_First_Site_2013_12_df['longitude'] = JNorth_Egg_First_Site_2013_12_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2013_12_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2013_12.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # 2014

# %%
JNorth_Egg_First_Site_2014_df = JNorth_Egg_First_Site_year_df[JNorth_Egg_First_Site_year_df['year']==2014]
JNorth_Egg_First_Site_2014_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2602    2014-07-20  Monarch Egg (FIRST sighted)    44.631    -72.567       1
# 2603    2014-07-22  Monarch Egg (FIRST sighted)    41.309    -81.062       1
# 2604    2014-07-22  Monarch Egg (FIRST sighted)    43.956    -69.500       1
# 2605    2014-07-24  Monarch Egg (FIRST sighted)    44.535    -73.056       1
# 2606    2014-12-20  Monarch Egg (FIRST sighted)    28.035    -82.389       1
#
#       year
# 2602  2014
# 2603  2014
# 2604  2014
# 2605  2014
# 2606  2014

# %%
JNorth_Egg_First_Site_2014_df.shape
# Out:
# (340, 6)

# %%
JNorth_Egg_First_Site_2014_df = pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_df.drop(['year'], axis=1, inplace=True)

# %%
JNorth_Egg_First_Site_2014_df.tail
# Out:
# <bound method NDFrame.tail of      sighting_date                      species  latitude  longitude  number
# 2267    2014-01-16  Monarch Egg (FIRST sighted)    33.917   -118.401       1
# 2268    2014-01-21  Monarch Egg (FIRST sighted)    25.778    -80.198       1
# 2269    2014-02-01  Monarch Egg (FIRST sighted)    26.381    -80.171       1
# 2270    2014-02-08  Monarch Egg (FIRST sighted)    34.156   -118.132       1
# 2271    2014-02-17  Monarch Egg (FIRST sighted)    29.757    -95.365       1
# ...            ...                          ...       ...        ...     ...
# 2602    2014-07-20  Monarch Egg (FIRST sighted)    44.631    -72.567       1
# 2603    2014-07-22  Monarch Egg (FIRST sighted)    41.309    -81.062       1
# 2604    2014-07-22  Monarch Egg (FIRST sighted)    43.956    -69.500       1
# 2605    2014-07-24  Monarch Egg (FIRST sighted)    44.535    -73.056       1
# 2606    2014-12-20  Monarch Egg (FIRST sighted)    28.035    -82.389       1
#
# ...

# %%
JNorth_Egg_First_Site_2014_df['month'] = pd.DatetimeIndex(JNorth_Egg_First_Site_2014_df['sighting_date']).month

# %% [markdown]
# ## January

# %%
JNorth_Egg_First_Site_2014_month_df =pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_1_df = JNorth_Egg_First_Site_2014_month_df[JNorth_Egg_First_Site_2014_month_df['month']==1]
JNorth_Egg_First_Site_2014_1_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2267    2014-01-16  Monarch Egg (FIRST sighted)    33.917   -118.401       1
# 2268    2014-01-21  Monarch Egg (FIRST sighted)    25.778    -80.198       1
#
#       month
# 2267      1
# 2268      1

# %%
JNorth_Egg_First_Site_2014_1_df.shape
# Out:
# (2, 6)

# %%
JNorth_Egg_First_Site_2014_1_df = pd.DataFrame(JNorth_Egg_First_Site_2014_1_df)
JNorth_Egg_First_Site_2014_1_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2014_1_df['latitude'] = JNorth_Egg_First_Site_2014_1_df['latitude'].astype(float)
JNorth_Egg_First_Site_2014_1_df['longitude'] = JNorth_Egg_First_Site_2014_1_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2014_1_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2014_1.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## February

# %%
JNorth_Egg_First_Site_2014_month_df =pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_2_df = JNorth_Egg_First_Site_2014_month_df[JNorth_Egg_First_Site_2014_month_df['month']==2]
JNorth_Egg_First_Site_2014_2_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2270    2014-02-08  Monarch Egg (FIRST sighted)    34.156   -118.132       1
# 2271    2014-02-17  Monarch Egg (FIRST sighted)    29.757    -95.365       1
# 2272    2014-02-23  Monarch Egg (FIRST sighted)    30.230    -97.714       1
# 2273    2014-02-24  Monarch Egg (FIRST sighted)    30.230    -97.714       1
# 2274    2014-02-27  Monarch Egg (FIRST sighted)    28.035    -82.389       1
#
#       month
# 2270      2
# 2271      2
# 2272      2
# 2273      2
# 2274      2

# %%
JNorth_Egg_First_Site_2014_2_df.shape
# Out:
# (6, 6)

# %%
JNorth_Egg_First_Site_2014_2_df = pd.DataFrame(JNorth_Egg_First_Site_2014_2_df)
JNorth_Egg_First_Site_2014_2_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2014_2_df['latitude'] = JNorth_Egg_First_Site_2014_2_df['latitude'].astype(float)
JNorth_Egg_First_Site_2014_2_df['longitude'] = JNorth_Egg_First_Site_2014_2_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2014_2_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2014_2.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## March

# %%
JNorth_Egg_First_Site_2014_month_df =pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_3_df = JNorth_Egg_First_Site_2014_month_df[JNorth_Egg_First_Site_2014_month_df['month']==3]
JNorth_Egg_First_Site_2014_3_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2296    2014-03-29  Monarch Egg (FIRST sighted)    29.646    -82.326       1
# 2297    2014-03-29  Monarch Egg (FIRST sighted)    30.370    -95.820       1
# 2298    2014-03-30  Monarch Egg (FIRST sighted)    30.498    -84.333       1
# 2299    2014-03-31  Monarch Egg (FIRST sighted)    29.821    -98.751       1
# 2300    2014-03-31  Monarch Egg (FIRST sighted)    32.933    -97.074       1
#
#       month
# 2296      3
# 2297      3
# 2298      3
# 2299      3
# 2300      3

# %%
JNorth_Egg_First_Site_2014_3_df.shape
# Out:
# (26, 6)

# %%
JNorth_Egg_First_Site_2014_3_df = pd.DataFrame(JNorth_Egg_First_Site_2014_3_df)
JNorth_Egg_First_Site_2014_3_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2014_3_df['latitude'] = JNorth_Egg_First_Site_2014_3_df['latitude'].astype(float)
JNorth_Egg_First_Site_2014_3_df['longitude'] = JNorth_Egg_First_Site_2014_3_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2014_3_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2014_3.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## April

# %%
JNorth_Egg_First_Site_2014_month_df =pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_4_df = JNorth_Egg_First_Site_2014_month_df[JNorth_Egg_First_Site_2014_month_df['month']==4]
JNorth_Egg_First_Site_2014_4_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2339    2014-04-28  Monarch Egg (FIRST sighted)    34.834    -82.846       1
# 2340    2014-04-28  Monarch Egg (FIRST sighted)    35.980    -95.808       1
# 2341    2014-04-29  Monarch Egg (FIRST sighted)    35.998    -86.787       1
# 2342    2014-04-29  Monarch Egg (FIRST sighted)    38.370    -90.810       1
# 2343    2014-04-30  Monarch Egg (FIRST sighted)    25.758    -80.143       1
#
#       month
# 2339      4
# 2340      4
# 2341      4
# 2342      4
# 2343      4

# %%
JNorth_Egg_First_Site_2014_4_df.shape
# Out:
# (43, 6)

# %%
JNorth_Egg_First_Site_2014_4_df = pd.DataFrame(JNorth_Egg_First_Site_2014_4_df)
JNorth_Egg_First_Site_2014_4_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2014_4_df['latitude'] = JNorth_Egg_First_Site_2014_4_df['latitude'].astype(float)
JNorth_Egg_First_Site_2014_4_df['longitude'] = JNorth_Egg_First_Site_2014_4_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2014_4_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2014_4.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## May

# %%
JNorth_Egg_First_Site_2014_month_df =pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_5_df = JNorth_Egg_First_Site_2014_month_df[JNorth_Egg_First_Site_2014_month_df['month']==5]
JNorth_Egg_First_Site_2014_5_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2463    2014-05-31  Monarch Egg (FIRST sighted)    43.027    -91.129       1
# 2464    2014-05-31  Monarch Egg (FIRST sighted)    43.048    -91.396       1
# 2465    2014-05-31  Monarch Egg (FIRST sighted)    43.176    -95.493       1
# 2466    2014-05-31  Monarch Egg (FIRST sighted)    44.648    -83.361       1
# 2467    2014-05-31  Monarch Egg (FIRST sighted)    44.968    -91.165       1
#
#       month
# 2463      5
# 2464      5
# 2465      5
# 2466      5
# 2467      5

# %%
JNorth_Egg_First_Site_2014_5_df.shape
# Out:
# (124, 6)

# %%
JNorth_Egg_First_Site_2014_5_df = pd.DataFrame(JNorth_Egg_First_Site_2014_5_df)
JNorth_Egg_First_Site_2014_5_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2014_5_df['latitude'] = JNorth_Egg_First_Site_2014_5_df['latitude'].astype(float)
JNorth_Egg_First_Site_2014_5_df['longitude'] = JNorth_Egg_First_Site_2014_5_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2014_5_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2014_5.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## June

# %%
JNorth_Egg_First_Site_2014_month_df =pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_6_df = JNorth_Egg_First_Site_2014_month_df[JNorth_Egg_First_Site_2014_month_df['month']==6]
JNorth_Egg_First_Site_2014_6_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2562    2014-06-29  Monarch Egg (FIRST sighted)    40.964    -91.558       1
# 2563    2014-06-29  Monarch Egg (FIRST sighted)    42.276    -84.181       1
# 2564    2014-06-29  Monarch Egg (FIRST sighted)    42.647    -82.930       1
# 2565    2014-06-29  Monarch Egg (FIRST sighted)    42.950    -82.117       1
# 2566    2014-06-29  Monarch Egg (FIRST sighted)    44.544    -83.354       1
#
#       month
# 2562      6
# 2563      6
# 2564      6
# 2565      6
# 2566      6

# %%
JNorth_Egg_First_Site_2014_6_df.shape
# Out:
# (99, 6)

# %%
JNorth_Egg_First_Site_2014_6_df = pd.DataFrame(JNorth_Egg_First_Site_2014_6_df)
JNorth_Egg_First_Site_2014_6_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2014_6_df['latitude'] = JNorth_Egg_First_Site_2014_6_df['latitude'].astype(float)
JNorth_Egg_First_Site_2014_6_df['longitude'] = JNorth_Egg_First_Site_2014_6_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2014_6_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2014_6.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## July

# %%
JNorth_Egg_First_Site_2014_month_df =pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_7_df = JNorth_Egg_First_Site_2014_month_df[JNorth_Egg_First_Site_2014_month_df['month']==7]
JNorth_Egg_First_Site_2014_7_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2601    2014-07-20  Monarch Egg (FIRST sighted)    44.539    -89.565       1
# 2602    2014-07-20  Monarch Egg (FIRST sighted)    44.631    -72.567       1
# 2603    2014-07-22  Monarch Egg (FIRST sighted)    41.309    -81.062       1
# 2604    2014-07-22  Monarch Egg (FIRST sighted)    43.956    -69.500       1
# 2605    2014-07-24  Monarch Egg (FIRST sighted)    44.535    -73.056       1
#
#       month
# 2601      7
# 2602      7
# 2603      7
# 2604      7
# 2605      7

# %%
JNorth_Egg_First_Site_2014_7_df.shape
# Out:
# (39, 6)

# %%
JNorth_Egg_First_Site_2014_7_df = pd.DataFrame(JNorth_Egg_First_Site_2014_7_df)
JNorth_Egg_First_Site_2014_7_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2014_7_df['latitude'] = JNorth_Egg_First_Site_2014_7_df['latitude'].astype(float)
JNorth_Egg_First_Site_2014_7_df['longitude'] = JNorth_Egg_First_Site_2014_7_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2014_7_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2014_7.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## August

# %%
JNorth_Egg_First_Site_2014_month_df =pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_8_df = JNorth_Egg_First_Site_2014_month_df[JNorth_Egg_First_Site_2014_month_df['month']==8]
JNorth_Egg_First_Site_2014_8_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2014_8_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2014_8_df= pd.DataFrame(JNorth_Egg_First_Site_2014_8_df)
JNorth_Egg_First_Site_2014_8_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2014_8_df['latitude'] = JNorth_Egg_First_Site_2014_8_df['latitude'].astype(float)
JNorth_Egg_First_Site_2014_8_df['longitude'] = JNorth_Egg_First_Site_2014_8_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2014_8_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2014_8.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## September

# %%
JNorth_Egg_First_Site_2014_month_df =pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_9_df = JNorth_Egg_First_Site_2014_month_df[JNorth_Egg_First_Site_2014_month_df['month']==9]
JNorth_Egg_First_Site_2014_9_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2014_9_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2014_9_df = pd.DataFrame(JNorth_Egg_First_Site_2014_9_df)
JNorth_Egg_First_Site_2014_9_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2014_9_df['latitude'] = JNorth_Egg_First_Site_2014_9_df['latitude'].astype(float)
JNorth_Egg_First_Site_2014_9_df['longitude'] = JNorth_Egg_First_Site_2014_9_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2014_9_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2014_9.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## October

# %%
JNorth_Egg_First_Site_2014_month_df =pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_10_df = JNorth_Egg_First_Site_2014_month_df[JNorth_Egg_First_Site_2014_month_df['month']==10]
JNorth_Egg_First_Site_2014_10_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2014_10_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2014_10_df = pd.DataFrame(JNorth_Egg_First_Site_2014_10_df)
JNorth_Egg_First_Site_2014_10_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2014_10_df['latitude'] = JNorth_Egg_First_Site_2014_10_df['latitude'].astype(float)
JNorth_Egg_First_Site_2014_10_df['longitude'] = JNorth_Egg_First_Site_2014_10_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2014_10_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2014_10.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## November

# %%
JNorth_Egg_First_Site_2014_month_df =pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_11_df = JNorth_Egg_First_Site_2014_month_df[JNorth_Egg_First_Site_2014_month_df['month']==11]
JNorth_Egg_First_Site_2014_11_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2014_11_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2014_11_df = pd.DataFrame(JNorth_Egg_First_Site_2014_11_df)
JNorth_Egg_First_Site_2014_11_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2014_11_df['latitude'] = JNorth_Egg_First_Site_2014_11_df['latitude'].astype(float)
JNorth_Egg_First_Site_2014_11_df['longitude'] = JNorth_Egg_First_Site_2014_11_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2014_11_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2014_11.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# ## December

# %%
JNorth_Egg_First_Site_2014_month_df =pd.DataFrame(JNorth_Egg_First_Site_2014_df)
JNorth_Egg_First_Site_2014_12_df = JNorth_Egg_First_Site_2014_month_df[JNorth_Egg_First_Site_2014_month_df['month']==12]
JNorth_Egg_First_Site_2014_12_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2606    2014-12-20  Monarch Egg (FIRST sighted)    28.035    -82.389       1
#
#       month
# 2606     12

# %%
JNorth_Egg_First_Site_2014_12_df.shape
# Out:
# (1, 6)

# %%
JNorth_Egg_First_Site_2014_12_df = pd.DataFrame(JNorth_Egg_First_Site_2014_12_df)
JNorth_Egg_First_Site_2014_12_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2014_12_df['latitude'] = JNorth_Egg_First_Site_2014_12_df['latitude'].astype(float)
JNorth_Egg_First_Site_2014_12_df['longitude'] = JNorth_Egg_First_Site_2014_12_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2014_12_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2014_12.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # 2015

# %%
JNorth_Egg_First_Site_2015_df = JNorth_Egg_First_Site_df[JNorth_Egg_First_Site_df['year']==2015]
JNorth_Egg_First_Site_2015_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 3050    2015-07-27  Monarch Egg (FIRST sighted)    42.840    -83.103       8
# 3051    2015-07-29  Monarch Egg (FIRST sighted)    45.067    -64.633       1
# 3052    2015-07-30  Monarch Egg (FIRST sighted)    39.107    -84.500       1
# 3053    2015-07-30  Monarch Egg (FIRST sighted)    41.074   -111.891       2
# 3054    2015-07-31  Monarch Egg (FIRST sighted)    43.754    -72.310       1
#
#       year
# 3050  2015
# 3051  2015
# 3052  2015
# 3053  2015
# 3054  2015

# %%
JNorth_Egg_First_Site_2015_df.shape
# Out:
# (448, 6)

# %%
JNorth_Egg_First_Site_2015_df = pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_df.drop(['year'], axis=1, inplace=True)

# %%
JNorth_Egg_First_Site_2015_df.tail
# Out:
# <bound method NDFrame.tail of      sighting_date                      species  latitude  longitude  number
# 2607    2015-01-01  Monarch Egg (FIRST sighted)    27.770    -82.637       1
# 2608    2015-01-03  Monarch Egg (FIRST sighted)    28.827    -82.256       1
# 2609    2015-01-12  Monarch Egg (FIRST sighted)    34.066   -118.810       1
# 2610    2015-01-24  Monarch Egg (FIRST sighted)    25.204    -80.362       1
# 2611    2015-02-04  Monarch Egg (FIRST sighted)    34.101   -118.055       1
# ...            ...                          ...       ...        ...     ...
# 3050    2015-07-27  Monarch Egg (FIRST sighted)    42.840    -83.103       8
# 3051    2015-07-29  Monarch Egg (FIRST sighted)    45.067    -64.633       1
# 3052    2015-07-30  Monarch Egg (FIRST sighted)    39.107    -84.500       1
# 3053    2015-07-30  Monarch Egg (FIRST sighted)    41.074   -111.891       2
# 3054    2015-07-31  Monarch Egg (FIRST sighted)    43.754    -72.310       1
#
# ...

# %%
JNorth_Egg_First_Site_2015_df['month'] = pd.DatetimeIndex(JNorth_Egg_First_Site_2015_df['sighting_date']).month

# %% [markdown]
# ## January

# %%
JNorth_Egg_First_Site_2015_month_df =pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_1_df = JNorth_Egg_First_Site_2015_month_df[JNorth_Egg_First_Site_2015_month_df['month']==1]
JNorth_Egg_First_Site_2015_1_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2607    2015-01-01  Monarch Egg (FIRST sighted)    27.770    -82.637       1
# 2608    2015-01-03  Monarch Egg (FIRST sighted)    28.827    -82.256       1
# 2609    2015-01-12  Monarch Egg (FIRST sighted)    34.066   -118.810       1
# 2610    2015-01-24  Monarch Egg (FIRST sighted)    25.204    -80.362       1
#
#       month
# 2607      1
# 2608      1
# 2609      1
# 2610      1

# %%
JNorth_Egg_First_Site_2015_1_df.shape
# Out:
# (4, 6)

# %%
JNorth_Egg_First_Site_2015_1_df = pd.DataFrame(JNorth_Egg_First_Site_2015_1_df)
JNorth_Egg_First_Site_2015_1_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2015_1_df['latitude'] = JNorth_Egg_First_Site_2015_1_df['latitude'].astype(float)
JNorth_Egg_First_Site_2015_1_df['longitude'] = JNorth_Egg_First_Site_2015_1_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2015_1_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2015_1.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # February

# %%
JNorth_Egg_First_Site_2015_month_df =pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_2_df = JNorth_Egg_First_Site_2015_month_df[JNorth_Egg_First_Site_2015_month_df['month']==2]
JNorth_Egg_First_Site_2015_2_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2611    2015-02-04  Monarch Egg (FIRST sighted)    34.101   -118.055       1
# 2612    2015-02-08  Monarch Egg (FIRST sighted)    29.996    -95.680       1
# 2613    2015-02-18  Monarch Egg (FIRST sighted)    32.760   -116.998       1
#
#       month
# 2611      2
# 2612      2
# 2613      2

# %%
JNorth_Egg_First_Site_2015_2_df.shape
# Out:
# (3, 6)

# %%
JNorth_Egg_First_Site_2015_2_df = pd.DataFrame(JNorth_Egg_First_Site_2015_2_df)
JNorth_Egg_First_Site_2015_2_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2015_2_df['latitude'] = JNorth_Egg_First_Site_2015_2_df['latitude'].astype(float)
JNorth_Egg_First_Site_2015_2_df['longitude'] = JNorth_Egg_First_Site_2015_2_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2015_2_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2015_2.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # March

# %%
JNorth_Egg_First_Site_2015_month_df =pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_3_df = JNorth_Egg_First_Site_2015_month_df[JNorth_Egg_First_Site_2015_month_df['month']==3]
JNorth_Egg_First_Site_2015_3_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2637    2015-03-29  Monarch Egg (FIRST sighted)    29.757    -95.365       1
# 2638    2015-03-30  Monarch Egg (FIRST sighted)    28.783    -81.739       1
# 2639    2015-03-31  Monarch Egg (FIRST sighted)    30.160    -95.185       1
# 2640    2015-03-31  Monarch Egg (FIRST sighted)    30.230    -97.714       1
# 2641    2015-03-31  Monarch Egg (FIRST sighted)    31.699    -98.981       1
#
#       month
# 2637      3
# 2638      3
# 2639      3
# 2640      3
# 2641      3

# %%
JNorth_Egg_First_Site_2015_3_df.shape
# Out:
# (28, 6)

# %%
JNorth_Egg_First_Site_2015_3_df = pd.DataFrame(JNorth_Egg_First_Site_2015_3_df)
JNorth_Egg_First_Site_2015_3_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2015_3_df['latitude'] = JNorth_Egg_First_Site_2015_3_df['latitude'].astype(float)
JNorth_Egg_First_Site_2015_3_df['longitude'] = JNorth_Egg_First_Site_2015_3_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2015_3_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2015_3.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # April

# %%
JNorth_Egg_First_Site_2015_month_df =pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_4_df = JNorth_Egg_First_Site_2015_month_df[JNorth_Egg_First_Site_2015_month_df['month']==4]
JNorth_Egg_First_Site_2015_4_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2720    2015-04-29  Monarch Egg (FIRST sighted)    38.826    -77.895       1
# 2721    2015-04-30  Monarch Egg (FIRST sighted)    33.772    -84.292       1
# 2722    2015-04-30  Monarch Egg (FIRST sighted)    34.748    -92.279       2
# 2723    2015-04-30  Monarch Egg (FIRST sighted)    36.240    -92.378       1
# 2724    2015-04-30  Monarch Egg (FIRST sighted)    36.798    -87.882       1
#
#       month
# 2720      4
# 2721      4
# 2722      4
# 2723      4
# 2724      4

# %%
JNorth_Egg_First_Site_2015_4_df.shape
# Out:
# (83, 6)

# %%
JNorth_Egg_First_Site_2015_4_df= pd.DataFrame(JNorth_Egg_First_Site_2015_4_df)
JNorth_Egg_First_Site_2015_4_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2015_4_df['latitude'] = JNorth_Egg_First_Site_2015_4_df['latitude'].astype(float)
JNorth_Egg_First_Site_2015_4_df['longitude'] = JNorth_Egg_First_Site_2015_4_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2015_4_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2015_4.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # May

# %%
JNorth_Egg_First_Site_2015_month_df =pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_5_df = JNorth_Egg_First_Site_2015_month_df[JNorth_Egg_First_Site_2015_month_df['month']==5]
JNorth_Egg_First_Site_2015_5_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2820    2015-05-31  Monarch Egg (FIRST sighted)    38.027    -98.087       1
# 2821    2015-05-31  Monarch Egg (FIRST sighted)    39.247   -120.642       1
# 2822    2015-05-31  Monarch Egg (FIRST sighted)    40.829    -98.438       1
# 2823    2015-05-31  Monarch Egg (FIRST sighted)    43.079    -89.377       1
# 2824    2015-05-31  Monarch Egg (FIRST sighted)    44.864    -93.429       1
#
#       month
# 2820      5
# 2821      5
# 2822      5
# 2823      5
# 2824      5

# %%
JNorth_Egg_First_Site_2015_5_df.shape
# Out:
# (100, 6)

# %%
JNorth_Egg_First_Site_2015_5_df = pd.DataFrame(JNorth_Egg_First_Site_2015_5_df)
JNorth_Egg_First_Site_2015_5_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2015_5_df['latitude'] = JNorth_Egg_First_Site_2015_5_df['latitude'].astype(float)
JNorth_Egg_First_Site_2015_5_df['longitude'] = JNorth_Egg_First_Site_2015_5_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2015_5_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2015_5.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # June

# %%
JNorth_Egg_First_Site_2015_month_df =pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_6_df = JNorth_Egg_First_Site_2015_month_df[JNorth_Egg_First_Site_2015_month_df['month']==6]
JNorth_Egg_First_Site_2015_6_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 2975    2015-06-29  Monarch Egg (FIRST sighted)    44.990    -81.240       1
# 2976    2015-06-30  Monarch Egg (FIRST sighted)    40.106   -105.166       1
# 2977    2015-06-30  Monarch Egg (FIRST sighted)    40.163    -75.276       1
# 2978    2015-06-30  Monarch Egg (FIRST sighted)    41.568    -87.549       1
# 2979    2015-06-30  Monarch Egg (FIRST sighted)    42.357    -83.903       6
#
#       month
# 2975      6
# 2976      6
# 2977      6
# 2978      6
# 2979      6

# %%
JNorth_Egg_First_Site_2015_6_df.shape
# Out:
# (155, 6)

# %%
JNorth_Egg_First_Site_2015_6_df = pd.DataFrame(JNorth_Egg_First_Site_2015_6_df)
JNorth_Egg_First_Site_2015_6_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2015_6_df['latitude'] = JNorth_Egg_First_Site_2015_6_df['latitude'].astype(float)
JNorth_Egg_First_Site_2015_6_df['longitude'] = JNorth_Egg_First_Site_2015_6_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2015_6_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2015_6.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # July

# %%
JNorth_Egg_First_Site_2015_month_df =pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_7_df = JNorth_Egg_First_Site_2015_month_df[JNorth_Egg_First_Site_2015_month_df['month']==7]
JNorth_Egg_First_Site_2015_7_df.tail()
# Out:
#      sighting_date                      species  latitude  longitude  number  \
# 3050    2015-07-27  Monarch Egg (FIRST sighted)    42.840    -83.103       8
# 3051    2015-07-29  Monarch Egg (FIRST sighted)    45.067    -64.633       1
# 3052    2015-07-30  Monarch Egg (FIRST sighted)    39.107    -84.500       1
# 3053    2015-07-30  Monarch Egg (FIRST sighted)    41.074   -111.891       2
# 3054    2015-07-31  Monarch Egg (FIRST sighted)    43.754    -72.310       1
#
#       month
# 3050      7
# 3051      7
# 3052      7
# 3053      7
# 3054      7

# %%
JNorth_Egg_First_Site_2015_7_df.shape
# Out:
# (75, 6)

# %%
JNorth_Egg_First_Site_2015_7_df = pd.DataFrame(JNorth_Egg_First_Site_2015_7_df)
JNorth_Egg_First_Site_2015_7_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2015_7_df['latitude'] = JNorth_Egg_First_Site_2015_7_df['latitude'].astype(float)
JNorth_Egg_First_Site_2015_7_df['longitude'] = JNorth_Egg_First_Site_2015_7_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2015_7_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2015_7.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # August

# %%
JNorth_Egg_First_Site_2015_month_df =pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_8_df = JNorth_Egg_First_Site_2015_month_df[JNorth_Egg_First_Site_2015_month_df['month']==8]
JNorth_Egg_First_Site_2015_8_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2015_8_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2015_8_df = pd.DataFrame(JNorth_Egg_First_Site_2015_8_df)
JNorth_Egg_First_Site_2015_8_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2015_8_df['latitude'] = JNorth_Egg_First_Site_2015_8_df['latitude'].astype(float)
JNorth_Egg_First_Site_2015_8_df['longitude'] = JNorth_Egg_First_Site_2015_8_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2015_8_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2015_8.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # September

# %%
JNorth_Egg_First_Site_2015_month_df =pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_9_df = JNorth_Egg_First_Site_2015_month_df[JNorth_Egg_First_Site_2015_month_df['month']==9]
JNorth_Egg_First_Site_2015_9_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2015_9_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2015_9_df = pd.DataFrame(JNorth_Egg_First_Site_2015_9_df)
JNorth_Egg_First_Site_2015_9_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2015_9_df['latitude'] = JNorth_Egg_First_Site_2015_9_df['latitude'].astype(float)
JNorth_Egg_First_Site_2015_9_df['longitude'] = JNorth_Egg_First_Site_2015_9_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2015_9_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2015_9.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # October

# %%
JNorth_Egg_First_Site_2015_month_df =pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_10_df = JNorth_Egg_First_Site_2015_month_df[JNorth_Egg_First_Site_2015_month_df['month']==10]
JNorth_Egg_First_Site_2015_10_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2015_10_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2015_10_df = pd.DataFrame(JNorth_Egg_First_Site_2015_10_df)
JNorth_Egg_First_Site_2015_10_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2015_10_df['latitude'] = JNorth_Egg_First_Site_2015_10_df['latitude'].astype(float)
JNorth_Egg_First_Site_2015_10_df['longitude'] = JNorth_Egg_First_Site_2015_10_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2015_10_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2015_10.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # November

# %%
JNorth_Egg_First_Site_2015_month_df =pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_11_df = JNorth_Egg_First_Site_2015_month_df[JNorth_Egg_First_Site_2015_month_df['month']==11]
JNorth_Egg_First_Site_2015_11_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2015_11_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2015_11_df = pd.DataFrame(JNorth_Egg_First_Site_2015_11_df)
JNorth_Egg_First_Site_2015_11_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2015_11_df['latitude'] = JNorth_Egg_First_Site_2015_11_df['latitude'].astype(float)
JNorth_Egg_First_Site_2015_11_df['longitude'] = JNorth_Egg_First_Site_2015_11_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2015_11_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2015_11.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()

# %% [markdown]
# # December

# %%
JNorth_Egg_First_Site_2015_month_df =pd.DataFrame(JNorth_Egg_First_Site_2015_df)
JNorth_Egg_First_Site_2015_12_df = JNorth_Egg_First_Site_2015_month_df[JNorth_Egg_First_Site_2015_month_df['month']==12]
JNorth_Egg_First_Site_2015_12_df.tail()
# Out:
# Empty DataFrame
# Columns: [sighting_date, species, latitude, longitude, number, month]
# Index: []

# %%
JNorth_Egg_First_Site_2015_12_df.shape
# Out:
# (0, 6)

# %%
JNorth_Egg_First_Site_2015_12_df = pd.DataFrame(JNorth_Egg_First_Site_2015_12_df)
JNorth_Egg_First_Site_2015_12_df.drop(['month'], axis=1, inplace=True)

# %%
# convert lat-long to floats and change address from ALL CAPS to regular capitalization
JNorth_Egg_First_Site_2015_12_df['latitude'] = JNorth_Egg_First_Site_2015_12_df['latitude'].astype(float)
JNorth_Egg_First_Site_2015_12_df['longitude'] = JNorth_Egg_First_Site_2015_12_df['longitude'].astype(float)
# JNorth_Milkweed_Site_df['street_address'] = JNorth_Milkweed_Site_df['street_address'].str.title()

# %%
geojson = df_to_geojson(JNorth_Egg_First_Site_2015_12_df, cols)

# %%
file = open("JNorth_Egg_First_Site_2015_12.geojson", "w")
json.dump(geojson, file, indent =1)
file.close()
