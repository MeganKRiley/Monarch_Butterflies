# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from datetime import datetime

# %%
df = pd.read_csv(Path('JNorth_Adult_Site.csv'))
df.head()
# Out:
# C:\conda\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0         id sighting_date                species  number  \
# 0           0  850841703    12/16/1996  Monarch Adult Sighted       1
# 1           1  851824801     12/6/1996  Monarch Adult Sighted       1
# 2           2  854409931     9/21/1996  Monarch Adult Sighted       1
# 3           3  854557206     9/21/1996  Monarch Adult Sighted       1
# 4           4  855061862      1/1/1997  Monarch Adult Sighted       1
#
#    latitude  longitude  flag_location  \
# 0    27.594    -81.362              0
# 1    30.420    -87.224              0
# 2    40.817    -96.710              0
# 3    40.817    -96.710              0
# 4    34.244    -77.946              0
#
#                                             comments  \
# 0  On the ballfield a solitary monarch butterfly ...
# 1  Our 5th grade Discovery students who went alon...
# 2  We saw several hundred monarchs in our school ...
# 3  Over a hundered monarchs in our school butterf...
# 4  I Thought I Saw It, But I Was Suprised To See ...
#
#                            school  grade    image_url  customerid  number_old  \
# 0  Walker memorial junior academy   10.0  -999999.999         135 -999999.999
# 1      Hambrick elementary school    5.0  -999999.999         150 -999999.999
# 2                     -999999.999    5.0  -999999.999     9701054 -999999.999
# 3     Fredstrom elementary school    6.0  -999999.999         175 -999999.999
# 4                         Gregory    3.0  -999999.999         181 -999999.999
#
#    flag_number        species_old  flag_species
# 0            1  Monarch Butterfly             1
# 1            1  Monarch Butterfly             1
# 2            1  Monarch Butterfly             1
# 3            1  Monarch Butterfly             1
# 4            1  Monarch Butterfly             1

# %%
# adding a column for year
#df = df.astype({'sighting_date': 'datetime64[ns]'})
#df['sighting_date'] =  pd.to_datetime(df['sighting_date'], format='%m/%d/%Y')
df['year'] = pd.DatetimeIndex(df['sighting_date']).year
df['year'] = pd.to_datetime(df.year, format='%Y')
#df['sighting_date'] =  pd.to_datetime(df['sighting_date'], format='%Y')
#df = df.astype({'year': 'datetime64[ns]'})
#df['year'] = df['year'].astype(date)
# changing year into date
#df['year'] = df.year.strftime("%Y%m%d")
#df.dtypes
df.head()
# Out:
#    Unnamed: 0         id sighting_date                species  number  \
# 0           0  850841703    12/16/1996  Monarch Adult Sighted       1
# 1           1  851824801     12/6/1996  Monarch Adult Sighted       1
# 2           2  854409931     9/21/1996  Monarch Adult Sighted       1
# 3           3  854557206     9/21/1996  Monarch Adult Sighted       1
# 4           4  855061862      1/1/1997  Monarch Adult Sighted       1
#
#    latitude  longitude  flag_location  \
# 0    27.594    -81.362              0
# 1    30.420    -87.224              0
# 2    40.817    -96.710              0
# 3    40.817    -96.710              0
# 4    34.244    -77.946              0
#
#                                             comments  \
# 0  On the ballfield a solitary monarch butterfly ...
# 1  Our 5th grade Discovery students who went alon...
# 2  We saw several hundred monarchs in our school ...
# 3  Over a hundered monarchs in our school butterf...
# 4  I Thought I Saw It, But I Was Suprised To See ...
#
#                            school  grade    image_url  customerid  number_old  \
# 0  Walker memorial junior academy   10.0  -999999.999         135 -999999.999
# 1      Hambrick elementary school    5.0  -999999.999         150 -999999.999
# 2                     -999999.999    5.0  -999999.999     9701054 -999999.999
# 3     Fredstrom elementary school    6.0  -999999.999         175 -999999.999
# 4                         Gregory    3.0  -999999.999         181 -999999.999
#
#    flag_number        species_old  flag_species       year
# 0            1  Monarch Butterfly             1 1996-01-01
# 1            1  Monarch Butterfly             1 1996-01-01
# 2            1  Monarch Butterfly             1 1996-01-01
# 3            1  Monarch Butterfly             1 1996-01-01
# 4            1  Monarch Butterfly             1 1997-01-01

# %%
# Adding a column for month

df['month'] = pd.DatetimeIndex(df['sighting_date']).month
df.head()
# Out:
#    Unnamed: 0         id sighting_date                species  number  \
# 0           0  850841703    12/16/1996  Monarch Adult Sighted       1
# 1           1  851824801     12/6/1996  Monarch Adult Sighted       1
# 2           2  854409931     9/21/1996  Monarch Adult Sighted       1
# 3           3  854557206     9/21/1996  Monarch Adult Sighted       1
# 4           4  855061862      1/1/1997  Monarch Adult Sighted       1
#
#    latitude  longitude  flag_location  \
# 0    27.594    -81.362              0
# 1    30.420    -87.224              0
# 2    40.817    -96.710              0
# 3    40.817    -96.710              0
# 4    34.244    -77.946              0
#
#                                             comments  \
# 0  On the ballfield a solitary monarch butterfly ...
# 1  Our 5th grade Discovery students who went alon...
# 2  We saw several hundred monarchs in our school ...
# 3  Over a hundered monarchs in our school butterf...
# 4  I Thought I Saw It, But I Was Suprised To See ...
#
#                            school  grade    image_url  customerid  number_old  \
# 0  Walker memorial junior academy   10.0  -999999.999         135 -999999.999
# 1      Hambrick elementary school    5.0  -999999.999         150 -999999.999
# 2                     -999999.999    5.0  -999999.999     9701054 -999999.999
# 3     Fredstrom elementary school    6.0  -999999.999         175 -999999.999
# 4                         Gregory    3.0  -999999.999         181 -999999.999
#
#    flag_number        species_old  flag_species       year  month
# 0            1  Monarch Butterfly             1 1996-01-01     12
# 1            1  Monarch Butterfly             1 1996-01-01     12
# 2            1  Monarch Butterfly             1 1996-01-01      9
# 3            1  Monarch Butterfly             1 1996-01-01      9
# 4            1  Monarch Butterfly             1 1997-01-01      1

# %%
# combining the year and month
#df['month_and_year'] = pd.to_datetime(df.year.astype(str) + '-' + df.month.astype(str))
#df.head()

# %%
dfthirtytothirtyfive = df.loc[(df["latitude"] >= 30) & (df["latitude"] < 35)]
dfthirtytothirtyfive.head()
# Out:
#     Unnamed: 0         id sighting_date                species  number  \
# 1            1  851824801     12/6/1996  Monarch Adult Sighted       1
# 4            4  855061862      1/1/1997  Monarch Adult Sighted       1
# 20          20  858699143     3/11/1997  Monarch Adult Sighted       1
# 22          22  858699684     3/12/1997  Monarch Adult Sighted       1
# 24          24  858733649     3/13/1997  Monarch Adult Sighted       1
#
#     latitude  longitude  flag_location  \
# 1     30.420    -87.224              0
# 4     34.244    -77.946              0
# 20    30.540    -96.725              0
# 22    30.230    -97.714              0
# 24    30.832    -96.575              0
#
#                                              comments  \
# 1   Our 5th grade Discovery students who went alon...
# 4   I Thought I Saw It, But I Was Suprised To See ...
# 20  We saw a bunch of monarchs.  Caldwell is near ...
# 22  I saw monarchs on the UT campus and around the...
# 24  I wish I had known about your effort earlier. ...
#
#                         school  grade    image_url  customerid  number_old  \
# 1   Hambrick elementary school    5.0  -999999.999         150 -999999.999
# 4                      Gregory    3.0  -999999.999         181 -999999.999
# 20  First colony middle school    7.0  -999999.999     9702619 -999999.999
# 22  First colony middle school    7.0  -999999.999     9702619 -999999.999
# 24          Hearne high school    9.0  -999999.999     9702602       0.000
#
#     flag_number        species_old  flag_species       year  month
# 1             1  Monarch Butterfly             1 1996-01-01     12
# 4             1  Monarch Butterfly             1 1997-01-01      1
# 20            1  Monarch Butterfly             1 1997-01-01      3
# 22            1  Monarch Butterfly             1 1997-01-01      3
# 24            2  Monarch Butterfly             1 1997-01-01      3

# %%
# grouping by month and assuring month isn't an index
counts = df.groupby(["year"]).count()
counts = counts.reset_index()
counts.head(200)
# Out:
#          year  Unnamed: 0     id  sighting_date  species  number  latitude  \
# 0  1996-01-01           6      6              6        6       6         6
# 1  1997-01-01         704    704            704      704     704       704
# 2  1998-01-01         492    492            492      492     492       492
# 3  1999-01-01          59     59             59       59      59        59
# 4  2000-01-01          29     29             29       29      29        29
# 5  2001-01-01           3      3              3        3       3         3
# 6  2002-01-01          53     53             53       53      53        53
# 7  2003-01-01          39     39             39       39      39        39
# 8  2004-01-01          31     31             31       31      31        31
# 9  2005-01-01          47     47             47       47      47        47
# 10 2006-01-01          68     68             68       68      68        68
# 11 2007-01-01          23     23             23       23      23        23
# 12 2008-01-01          55     55             55       55      55        55
# 13 2009-01-01         167    167            167      167     167       167
# 14 2010-01-01        3287   3287           3287     3287    3287      3287
# 15 2011-01-01        4300   4300           4300     4300    4300      4300
# 16 2012-01-01        3509   3509           3509     3509    3509      3509
# 17 2013-01-01        4333   4333           4333     4333    4333      4333
# 18 2014-01-01        6598   6598           6598     6598    6598      6598
# 19 2015-01-01        8831   8831           8831     8831    8831      8831
# 20 2016-01-01       13642  13642          13642    13642   13642     13642
# 21 2017-01-01       14471  14471          14471    14471   14471     14471
# 22 2018-01-01       14536  14536          14536    14536   14536     14536
# 23 2019-01-01       13742  13742          13742    13742   13742     13742
# 24 2020-01-01       13281  13281          13281    13281   13281     13281
#
#     longitude  flag_location  comments  school  grade  image_url  customerid  \
# 0           6              6         6       6      6          6           6
# 1         704            704       704     704    704        704         704
# 2         492            492       492     492    492        492         492
# 3          59             59        59      59     59         59          59
# 4          29             29        29      29     29         29          29
# 5           3              3         3       3      3          3           3
# 6          53             53        53      53     53         53          53
# 7          39             39        39      39     39         39          39
# 8          31             31        31      31     31         31          31
# 9          47             47        47      47     47         47          47
# 10         68             68        68      68     68         68          68
# 11         23             23        23      23     23         23          23
# 12         55             55        55      55     55         55          55
# 13        167            167       167     167    167        167         167
# 14       3287           3287      3287    3287   3287       3287        3287
# 15       4300           4300      4300    4300   4300       4300        4300
# 16       3509           3509      3509    3509   3509       3509        3509
# 17       4333           4333      4333    4333   4333       4333        4333
# 18       6598           6598      6598    6598   6598       6598        6598
# 19       8831           8831      8831    8831   8831       8831        8831
# 20      13642          13642     13642   13642  13642      13642       13642
# 21      14471          14471     14471   14471  14471      14471       14471
# 22      14536          14536     14536   14536  14536      14536       14536
# 23      13742          13742     13742   13742  13742      13742       13742
# 24      13281          13281     13281   13281  13281      13281       13281
#
#     number_old  flag_number  species_old  flag_species  month
# 0            6            6            6             6      6
# 1          704          704          704           704    704
# 2          492          492          492           492    492
# 3           59           59           59            59     59
# 4           29           29           29            29     29
# 5            3            3            3             3      3
# 6           53           53           53            53     53
# 7           39           39           39            39     39
# 8           31           31           31            31     31
# 9           47           47           47            47     47
# 10          68           68           68            68     68
# 11          23           23           23            23     23
# 12          55           55           55            55     55
# 13         167          167          167           167    167
# 14        3287         3287         3287          3287   3287
# 15        4300         4300         4300          4300   4300
# 16        3509         3509         3509          3509   3509
# 17        4333         4333         4333          4333   4333
# 18        6598         6598         6598          6598   6598
# 19        8831         8831         8831          8831   8831
# 20       13642        13642        13642         13642  13642
# 21       14471        14471        14471         14471  14471
# 22       14536        14536        14536         14536  14536
# 23       13742        13742        13742         13742  13742
# 24       13281        13281        13281         13281  13281

# %%
# initial graph. note y-axis with counts.Date is a COUNT of total dates grouped by month; it is not the actual date
fig = plt.figure(figsize=(20, 10))
plt.scatter(counts.year, counts.sighting_date)
plt.xlabel('Years')
plt.ylabel('Butterfly Counts')

plt.show()

# %%
# using reshape
counts["year"] = counts["year"].apply(lambda x: x.toordinal())
# using reshape
X = counts.year.values.reshape(-1, 1)

# %%
# setting the y axis as the count of dates
y = counts.sighting_date.values.reshape(-1, 1)

# %%
# Training the data set

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)
  
#regr = LinearRegression()
  
#regr.fit(X_train, y_train)
#print(regr.score(X_test, y_test))
#print(r2_score(y_test, regr.predict(X_test)))

# %%
print(X)
# Out:
# [[728659]
#  [729025]
#  [729390]
#  [729755]
#  [730120]
#  [730486]
#  [730851]
#  [731216]
#  [731581]
#  [731947]
#  [732312]
#  [732677]
#  [733042]
#  [733408]
#  [733773]
#  [734138]
#  [734503]
#  [734869]
#  [735234]
#  [735599]
#  [735964]
#  [736330]
#  [736695]
#  [737060]
#  [737425]]

# %%
# setting the model
model = LinearRegression()

# %%
# fitting the model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# number of predictions
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (25, 1)

# %%
# a straight line for linear regression
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
# creating a polynomial function that allows us to input degrees for fitting
def fit_and_plot_poly_deg(degree):
    poly_feat = PolynomialFeatures(degree)
    X_poly = poly_feat.fit_transform(X)
    
    print('X_poly shape is: {}'.format(str(X_poly.shape)))

    poly_model = LinearRegression().fit(X_poly, y)
    y_pred = poly_model.predict(X_poly)

    plt.scatter(X, y, zorder=3)
    plt.plot(X, y_pred, color='black');

# %%
# two degree fit
fit_and_plot_poly_deg(2)
# Out:
# X_poly shape is: (25, 3)

# %%
# 3rd degree fit
fit_and_plot_poly_deg(3)
# Out:
# X_poly shape is: (25, 4)

# %%
# 4th degree
fit_and_plot_poly_deg(6)
# Out:
# X_poly shape is: (25, 7)
