# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import datetime

# %%
df = pd.read_csv(Path('JNorth_Peak_Migration.csv'))
df.head()
df.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# sighting_date     object
# species           object
# number             int64
# latitude         float64
# longitude        float64
# flag_location      int64
# comments          object
# school            object
# grade            float64
# image_url         object
# customerid         int64
# number_old       float64
# flag_number        int64
# species_old       object
# flag_species       int64
# dtype: object

# %%
# adding a column for year
df['year'] = pd.DatetimeIndex(df['sighting_date']).year
df.head()
df.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# sighting_date     object
# species           object
# number             int64
# latitude         float64
# longitude        float64
# flag_location      int64
# comments          object
# school            object
# grade            float64
# image_url         object
# customerid         int64
# number_old       float64
# flag_number        int64
# species_old       object
# flag_species       int64
# year               int64
# dtype: object

# %%
# Adding a column for month

df['month'] = pd.DatetimeIndex(df['sighting_date']).month
df.head()
# Out:
#    Unnamed: 0         id sighting_date                 species  number  \
# 0        3541  966119477    2000-08-08  Monarch PEAK Migration       1
# 1        3544  966258999    2000-08-15  Monarch PEAK Migration       1
# 2        3547  966374597    2000-08-15  Monarch PEAK Migration       1
# 3        3551  966612408    2000-08-17  Monarch PEAK Migration       1
# 4        3572  966879879    2000-08-20  Monarch PEAK Migration       1
#
#    latitude  longitude  flag_location  \
# 0    47.066    -94.504              0
# 1    44.957    -93.540              0
# 2    45.009    -93.340              0
# 3    45.050    -93.210              0
# 4    46.926    -96.850              0
#
#                                             comments        school  \
# 0  The first signs of the migration in Minnesota ...   -999999.999
# 1  I observed the first big pulse of fall migrati...   -999999.999
# 2  Lots of Monarch activity today!  We counted 58...  Breck school
# 3  The day was an exciting one. We had about 75 b...   -999999.999
# 4  It was totally awesome. It was about 4:30pm on...   -999999.999
#
#         grade    image_url  customerid  number_old  flag_number  \
# 0       0.000  -999999.999     9710973       0.000            2
# 1 -999999.999  -999999.999     9937188 -999999.999            1
# 2       4.000  -999999.999     9704118       0.000            2
# 3       0.000  -999999.999        2266       0.000            2
# 4 -999999.999  -999999.999     9900260 -999999.999            1
#
#               species_old  flag_species  year  month
# 0  Monarch PEAK Migration             0  2000      8
# 1  Monarch PEAK Migration             0  2000      8
# 2  Monarch PEAK Migration             0  2000      8
# 3  Monarch PEAK Migration             0  2000      8
# 4  Monarch PEAK Migration             0  2000      8

# %%
# combining the year and month
df['month_and_year'] = pd.to_datetime(df.year.astype(str) + '-' + df.month.astype(str))
df.head()
# Out:
#    Unnamed: 0         id sighting_date                 species  number  \
# 0        3541  966119477    2000-08-08  Monarch PEAK Migration       1
# 1        3544  966258999    2000-08-15  Monarch PEAK Migration       1
# 2        3547  966374597    2000-08-15  Monarch PEAK Migration       1
# 3        3551  966612408    2000-08-17  Monarch PEAK Migration       1
# 4        3572  966879879    2000-08-20  Monarch PEAK Migration       1
#
#    latitude  longitude  flag_location  \
# 0    47.066    -94.504              0
# 1    44.957    -93.540              0
# 2    45.009    -93.340              0
# 3    45.050    -93.210              0
# 4    46.926    -96.850              0
#
#                                             comments        school  \
# 0  The first signs of the migration in Minnesota ...   -999999.999
# 1  I observed the first big pulse of fall migrati...   -999999.999
# 2  Lots of Monarch activity today!  We counted 58...  Breck school
# 3  The day was an exciting one. We had about 75 b...   -999999.999
# 4  It was totally awesome. It was about 4:30pm on...   -999999.999
#
#         grade    image_url  customerid  number_old  flag_number  \
# 0       0.000  -999999.999     9710973       0.000            2
# 1 -999999.999  -999999.999     9937188 -999999.999            1
# 2       4.000  -999999.999     9704118       0.000            2
# 3       0.000  -999999.999        2266       0.000            2
# 4 -999999.999  -999999.999     9900260 -999999.999            1
#
#               species_old  flag_species  year  month month_and_year
# 0  Monarch PEAK Migration             0  2000      8     2000-08-01
# 1  Monarch PEAK Migration             0  2000      8     2000-08-01
# 2  Monarch PEAK Migration             0  2000      8     2000-08-01
# 3  Monarch PEAK Migration             0  2000      8     2000-08-01
# 4  Monarch PEAK Migration             0  2000      8     2000-08-01

# %%
# grouping by month and assuring month isn't an index
counts = df.groupby(["month_and_year"]).count()
counts = counts.reset_index()
counts.head(200)
# Out:
#    month_and_year  Unnamed: 0   id  sighting_date  species  number  latitude  \
# 0      2000-08-01          12   12             12       12      12        12
# 1      2000-09-01          73   73             73       73      73        73
# 2      2000-10-01          90   90             90       90      90        90
# 3      2000-12-01           1    1              1        1       1         1
# 4      2001-08-01          23   23             23       23      23        23
# ..            ...         ...  ...            ...      ...     ...       ...
# 84     2019-11-01          19   19             19       19      19        19
# 85     2020-08-01          20   20             20       20      20        20
# 86     2020-09-01         231  231            231      231     231       231
# 87     2020-10-01          95   95             95       95      95        95
# 88     2020-11-01           9    9              9        9       9         9
#
#     longitude  flag_location  comments  school  grade  image_url  customerid  \
# 0          12             12        12      12     12         12          12
# 1          73             73        73      73     73         73          73
# 2          90             90        90      90     90         90          90
# 3           1              1         1       1      1          1           1
# 4          23             23        23      23     23         23          23
# ..        ...            ...       ...     ...    ...        ...         ...
# 84         19             19        19      19     19         19          19
# 85         20             20        20      20     20         20          20
# 86        231            231       231     231    231        231         231
# 87         95             95        95      95     95         95          95
# 88          9              9         9       9      9          9           9
#
#     number_old  flag_number  species_old  flag_species  year  month
# 0           12           12           12            12    12     12
# 1           73           73           73            73    73     73
# 2           90           90           90            90    90     90
# 3            1            1            1             1     1      1
# 4           23           23           23            23    23     23
# ..         ...          ...          ...           ...   ...    ...
# 84          19           19           19            19    19     19
# 85          20           20           20            20    20     20
# 86         231          231          231           231   231    231
# 87          95           95           95            95    95     95
# 88           9            9            9             9     9      9
#
# [89 rows x 20 columns]

# %%
# initial graph. note y-axis with counts.Date is a COUNT of total dates grouped by month; it is not the actual date
fig = plt.figure(figsize=(40, 20))
plt.scatter(counts.month_and_year, counts.sighting_date)
plt.xlabel('Butterfly Counts')
plt.ylabel('Month')

plt.show()

# %%
# using reshape
counts["month_and_year"] = counts["month_and_year"].apply(lambda x: x.toordinal())
#counts["month_and_year"] = counts["month_and_year"].astype(float)
X = counts.month_and_year.values.reshape(-1, 1)

# %%
# setting the y axis as the count of dates
y = counts.sighting_date

# %%
# setting the model
model = LinearRegression()

# %%
# fitting the model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# number of predictions
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (89,)

# %%
# a straight line for linear regression
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
# creating a polynomial function that allows us to input degrees for fitting
def fit_and_plot_poly_deg(degree):
    poly_feat = PolynomialFeatures(degree)
    X_poly = poly_feat.fit_transform(X)
    
    print('X_poly shape is: {}'.format(str(X_poly.shape)))

    poly_model = LinearRegression().fit(X_poly, y)
    y_pred = poly_model.predict(X_poly)

    plt.scatter(X, y, zorder=3)
    plt.plot(X, y_pred, color='black');

# %%
# two degree fit
fit_and_plot_poly_deg(2)
# Out:
# X_poly shape is: (89, 3)

# %%
# 3rd degree fit
fit_and_plot_poly_deg(3)
# Out:
# X_poly shape is: (89, 4)

# %%
# 4th degree
fit_and_plot_poly_deg(4)
# Out:
# X_poly shape is: (89, 5)
