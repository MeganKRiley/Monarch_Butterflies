# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from datetime import datetime

# %%
df = pd.read_csv(Path('JNorth_Adult_Site.csv'))
df.head()
# Out:
# C:\conda\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0         id sighting_date                species  number  \
# 0           0  850841703    12/16/1996  Monarch Adult Sighted       1
# 1           1  851824801     12/6/1996  Monarch Adult Sighted       1
# 2           2  854409931     9/21/1996  Monarch Adult Sighted       1
# 3           3  854557206     9/21/1996  Monarch Adult Sighted       1
# 4           4  855061862      1/1/1997  Monarch Adult Sighted       1
#
#    latitude  longitude  flag_location  \
# 0    27.594    -81.362              0
# 1    30.420    -87.224              0
# 2    40.817    -96.710              0
# 3    40.817    -96.710              0
# 4    34.244    -77.946              0
#
#                                             comments  \
# 0  On the ballfield a solitary monarch butterfly ...
# 1  Our 5th grade Discovery students who went alon...
# 2  We saw several hundred monarchs in our school ...
# 3  Over a hundered monarchs in our school butterf...
# 4  I Thought I Saw It, But I Was Suprised To See ...
#
#                            school  grade    image_url  customerid  number_old  \
# 0  Walker memorial junior academy   10.0  -999999.999         135 -999999.999
# 1      Hambrick elementary school    5.0  -999999.999         150 -999999.999
# 2                     -999999.999    5.0  -999999.999     9701054 -999999.999
# 3     Fredstrom elementary school    6.0  -999999.999         175 -999999.999
# 4                         Gregory    3.0  -999999.999         181 -999999.999
#
#    flag_number        species_old  flag_species
# 0            1  Monarch Butterfly             1
# 1            1  Monarch Butterfly             1
# 2            1  Monarch Butterfly             1
# 3            1  Monarch Butterfly             1
# 4            1  Monarch Butterfly             1

# %%
# adding a column for year
#df = df.astype({'sighting_date': 'datetime64[ns]'})
#df['sighting_date'] =  pd.to_datetime(df['sighting_date'], format='%m/%d/%Y')
df['year'] = pd.DatetimeIndex(df['sighting_date']).year
df['year'] = pd.to_datetime(df.year, format='%Y')
#df['sighting_date'] =  pd.to_datetime(df['sighting_date'], format='%Y')
#df = df.astype({'year': 'datetime64[ns]'})
#df['year'] = df['year'].astype(date)
# changing year into date
#df['year'] = df.year.strftime("%Y%m%d")
#df.dtypes
df.head()
# Out:
#    Unnamed: 0         id sighting_date                species  number  \
# 0           0  850841703    12/16/1996  Monarch Adult Sighted       1
# 1           1  851824801     12/6/1996  Monarch Adult Sighted       1
# 2           2  854409931     9/21/1996  Monarch Adult Sighted       1
# 3           3  854557206     9/21/1996  Monarch Adult Sighted       1
# 4           4  855061862      1/1/1997  Monarch Adult Sighted       1
#
#    latitude  longitude  flag_location  \
# 0    27.594    -81.362              0
# 1    30.420    -87.224              0
# 2    40.817    -96.710              0
# 3    40.817    -96.710              0
# 4    34.244    -77.946              0
#
#                                             comments  \
# 0  On the ballfield a solitary monarch butterfly ...
# 1  Our 5th grade Discovery students who went alon...
# 2  We saw several hundred monarchs in our school ...
# 3  Over a hundered monarchs in our school butterf...
# 4  I Thought I Saw It, But I Was Suprised To See ...
#
#                            school  grade    image_url  customerid  number_old  \
# 0  Walker memorial junior academy   10.0  -999999.999         135 -999999.999
# 1      Hambrick elementary school    5.0  -999999.999         150 -999999.999
# 2                     -999999.999    5.0  -999999.999     9701054 -999999.999
# 3     Fredstrom elementary school    6.0  -999999.999         175 -999999.999
# 4                         Gregory    3.0  -999999.999         181 -999999.999
#
#    flag_number        species_old  flag_species       year
# 0            1  Monarch Butterfly             1 1996-01-01
# 1            1  Monarch Butterfly             1 1996-01-01
# 2            1  Monarch Butterfly             1 1996-01-01
# 3            1  Monarch Butterfly             1 1996-01-01
# 4            1  Monarch Butterfly             1 1997-01-01

# %%
filterdate = input("Which year do you want to look forward from?: ")

df = df.loc[(df["year"] >= filterdate)]
# Out:
# Which year do you want to look forward from?: 2016

# %%
# Adding a column for month

df['month'] = pd.DatetimeIndex(df['sighting_date']).month
df.head()
# Out:
#        Unnamed: 0          id sighting_date                species  number  \
# 32512       91164  1449525336      1/1/2016  Monarch Adult Sighted       1
# 32513       91165  1449525529      1/1/2016  Monarch Adult Sighted       1
# 32558       91306  1451875416      1/2/2016  Monarch Adult Sighted       1
# 32559       91308  1451954572      1/4/2016  Monarch Adult Sighted       1
# 32560       91310  1452108198      1/6/2016  Monarch Adult Sighted       1
#
#        latitude  longitude  flag_location  \
# 32512    19.670   -100.280              1
# 32513    19.590   -100.266              1
# 32558    36.315    -75.812              1
# 32559    28.864    -97.025              1
# 32560    28.179    -80.600              1
#
#                                                 comments       school  \
# 32512  <font size="4" face="Verdana, Arial, Helvetica...  -999999.999
# 32513  <div align="left"><strong><font size="5" face=...  -999999.999
# 32558  I saw one Monarch flying low over the grass on...  -999999.999
# 32559  After a week of cold rainy days(40's).  First ...  -999999.999
# 32560                       Tagged monarch tag # UNU 822  -999999.999
#
#             grade                                          image_url  \
# 32512 -999999.999                                        -999999.999
# 32513 -999999.999                                        -999999.999
# 32558 -999999.999                                        -999999.999
# 32559 -999999.999  https://journeynorth.org/jnorth/images/userfil...
# 32560 -999999.999  https://journeynorth.org/jnorth/images/userfil...
#
#        customerid  number_old  flag_number                    species_old  \
# 32512     9710973 -999999.999            1  Monarch Migration Sighting OW
# 32513     9710973 -999999.999            1  Monarch Migration Sighting OW
# 32558     9979544       1.000            0          Monarch Adult Sighted
# 32559     9988763       1.000            0          Monarch Adult Sighted
# 32560     9989296       1.000            0          Monarch Adult Sighted
#
#        flag_species       year  month
# 32512             1 2016-01-01      1
# 32513             1 2016-01-01      1
# 32558             0 2016-01-01      1
# 32559             0 2016-01-01      1
# 32560             0 2016-01-01      1

# %%
# combining the year and month
#df['month_and_year'] = pd.to_datetime(df.year.astype(str) + '-' + df.month.astype(str))
#df.head()

# %%
northlat = input("Enter the North latitude: ")
southlat = input("Enter the South latitude: ")
eastlat = input("Enter the East longitude: ")
westlat = input("Enter the West longitude: ")
# Out:
# Enter the North latitude: 40.92
# Enter the South latitude: 40.49
# Enter the East longitude: -73.7
# Enter the West longitude: -74.24

# %%
northlat = float(northlat)
southlat = float(southlat)
eastlat = float(eastlat)
westlat = float(westlat)

# %%
df = df.loc[(df["latitude"] >= southlat) & (df["latitude"] <= northlat) & (df["longitude"] >= westlat) & (df["longitude"] <= eastlat)]
df.head()
# Out:
#        Unnamed: 0          id sighting_date                species  number  \
# 33702       96648  1464663366     7/13/2016  Monarch Adult Sighted       1
# 33911       97231  1464664060     7/21/2016  Monarch Adult Sighted       1
# 33957       97338  1464664189     7/23/2016  Monarch Adult Sighted       2
# 33958       97339  1464664190     7/22/2016  Monarch Adult Sighted       1
# 34173       97857  1464664800     7/30/2016  Monarch Adult Sighted       2
#
#        latitude  longitude  flag_location  \
# 33702    40.865    -73.998              1
# 33911    40.865    -73.999              1
# 33957    40.787    -74.106              1
# 33958    40.886    -74.044              1
# 34173    40.787    -74.102              1
#
#                                                 comments       school  \
# 33702         One female laying eggs on Common Milkweed.  -999999.999
# 33911     One female depositing eggs on Common Milkweed.  -999999.999
# 33957         two females laying eggs on Common Milkweed  -999999.999
# 33958     One female depositing eggs on Common Milkweed.  -999999.999
# 34173  Two Monarchs nectaring, one was depositing egg...  -999999.999
#
#             grade                                          image_url  \
# 33702 -999999.999                                        -999999.999
# 33911 -999999.999                                        -999999.999
# 33957 -999999.999  https://journeynorth.org/jnorth/images/userfil...
# 33958 -999999.999                                        -999999.999
# 34173 -999999.999                                        -999999.999
#
#        customerid  number_old  flag_number            species_old  \
# 33702     9976759         1.0            0  Monarch Adult Sighted
# 33911     9976759         1.0            0  Monarch Adult Sighted
# 33957     9984872         2.0            0  Monarch Adult Sighted
# 33958     9976759         1.0            0  Monarch Adult Sighted
# 34173     9976759         2.0            0  Monarch Adult Sighted
#
#        flag_species       year  month
# 33702             0 2016-01-01      7
# 33911             0 2016-01-01      7
# 33957             0 2016-01-01      7
# 33958             0 2016-01-01      7
# 34173             0 2016-01-01      7

# %%
# grouping by month and assuring month isn't an index
counts = df.groupby(["year"]).count()
counts = counts.reset_index()
counts.head(200)
# Out:
#         year  Unnamed: 0   id  sighting_date  species  number  latitude  \
# 0 2016-01-01         121  121            121      121     121       121
# 1 2017-01-01         188  188            188      188     188       188
# 2 2018-01-01         151  151            151      151     151       151
# 3 2019-01-01         199  199            199      199     199       199
# 4 2020-01-01          70   70             70       70      70        70
#
#    longitude  flag_location  comments  school  grade  image_url  customerid  \
# 0        121            121       121     121    121        121         121
# 1        188            188       188     188    188        188         188
# 2        151            151       151     151    151        151         151
# 3        199            199       199     199    199        199         199
# 4         70             70        70      70     70         70          70
#
#    number_old  flag_number  species_old  flag_species  month
# 0         121          121          121           121    121
# 1         188          188          188           188    188
# 2         151          151          151           151    151
# 3         199          199          199           199    199
# 4          70           70           70            70     70

# %%
# initial graph. note y-axis with counts.Date is a COUNT of total dates grouped by month; it is not the actual date
fig = plt.figure(figsize=(20, 10))
plt.scatter(counts.year, counts.sighting_date)
plt.xlabel('Years')
plt.ylabel('Butterfly Counts')

plt.show()

# %%
# using reshape
counts["year"] = counts["year"].apply(lambda x: x.toordinal())
# using reshape
X = counts.year.values.reshape(-1, 1)

# %%
# setting the y axis as the count of dates
y = counts.sighting_date.values.reshape(-1, 1)

# %%
# Training the data set

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)
  
#regr = LinearRegression()
  
#regr.fit(X_train, y_train)
#print(regr.score(X_test, y_test))
#print(r2_score(y_test, regr.predict(X_test)))

# %%
print(X)
# Out:
# [[735964]
#  [736330]
#  [736695]
#  [737060]
#  [737425]]

# %%
# setting the model
model = LinearRegression()

# %%
# fitting the model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# number of predictions
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (5, 1)

# %%
# a straight line for linear regression
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
# creating a polynomial function that allows us to input degrees for fitting
def fit_and_plot_poly_deg(degree):
    poly_feat = PolynomialFeatures(degree)
    X_poly = poly_feat.fit_transform(X)
    
    print('X_poly shape is: {}'.format(str(X_poly.shape)))

    poly_model = LinearRegression().fit(X_poly, y)
    y_pred = poly_model.predict(X_poly)

    plt.scatter(X, y, zorder=3)
    plt.plot(X, y_pred, color='black');

# %%
# two degree fit
fit_and_plot_poly_deg(2)
# Out:
# X_poly shape is: (5, 3)

# %%
# 3rd degree fit
fit_and_plot_poly_deg(3)
# Out:
# X_poly shape is: (5, 4)

# %%
# 4th degree
fit_and_plot_poly_deg(6)
# Out:
# X_poly shape is: (5, 7)
